# %% [markdown]
# ## Importing the files

# %% [markdown]
# Load the *libraries.csv files and *.vuln.csv

# %%
import pandas as pd
import glob

# Load all libraries files
library_files = glob.glob('*.libraries.csv')
df_libraries_list = []
for file in library_files:
    df_temp = pd.read_csv(file)
    df_temp['source_file'] = file
    df_libraries_list.append(df_temp)

libraries_df = pd.concat(df_libraries_list, ignore_index=True)

# Load all vulnerability files
vuln_files = glob.glob('*.vuln.csv')
df_vulns_list = []
for file in vuln_files:
    df_temp = pd.read_csv(file)
    df_temp['source_file'] = file
    df_vulns_list.append(df_temp)

vulnerabilities_df = pd.concat(df_vulns_list, ignore_index=True)

print(f"{len(libraries_df)} library records loaded from {len(library_files)} files")
print(f"{len(vulnerabilities_df)} vulnerability loaded records from {len(vuln_files)} files")
# Out:
# 7338 library records loaded from 10 files
# 176 vulnerability loaded records from 10 files

# %% [markdown]
# ## List of libraries used by OSS Projects

# %%
project_counts = libraries_df['Project Name'].value_counts()
print(project_counts)
# Out:
# Project Name
# socket.io      1373
# jest           1227
# mongoose       1103
# axios           844
# dotenv          773
# chalk           750
# lodash          699
# bcrypt          293
# tailwindcss     237
# passport         39
# Name: count, dtype: int64

# %% [markdown]
# ## Top Libraries most used

# %%
library_counts = libraries_df['Library Name'].value_counts()
print(library_counts.head(15))
# Out:
# Library Name
# semver             60
# ansi-styles        58
# strip-ansi         46
# chalk              46
# minimatch          45
# debug              44
# type-fest          42
# supports-color     42
# brace-expansion    41
# string-width       41
# ansi-regex         39
# glob               37
# lru-cache          35
# p-limit            35
# minipass           35
# Name: count, dtype: int64

# %% [markdown]
# ## Most used ibraries by OSS projects

# %%
library_analysis = libraries_df.groupby('Library Name').agg({
    'Project Name': ['count', 'nunique']
}).reset_index()

# Flatten column names
library_analysis.columns = ['Library Name', 'Total_Usage', 'Used_by_Projects']

# Sort by total usage
library_analysis = library_analysis.sort_values('Total_Usage', ascending=False)

print(library_analysis.head(10))
# Out:
#          Library Name  Total_Usage  Used_by_Projects
# 1878           semver           60                 8
# 33        ansi-styles           58                 9
# 278             chalk           46                 8
# 1992       strip-ansi           46                 9
# 1284        minimatch           45                10
# 443             debug           44                10
# 2006   supports-color           42                 9
# 2116        type-fest           42                 8
# 220   brace-expansion           41                 9
# 1984     string-width           41                 9

# %% [markdown]
# ## Grap: Most used libraries

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource
from bokeh.io import push_notebook

# Enable Bokeh in Colab
output_notebook()

# Your data
library_analysis = libraries_df.groupby('Library Name').agg({
    'Project Name': ['count', 'nunique']
}).reset_index()

library_analysis.columns = ['Library Name', 'Total_Usage', 'Unique_Libraries']
library_analysis = library_analysis.sort_values('Total_Usage', ascending=False)

# Get top 20 libraries
top_20 = library_analysis.head(20)

# Create bokeh chart
source = ColumnDataSource(top_20)

p = figure(x_range=list(top_20['Library Name']),
           title="Top 20 Most Used Libraries in key Node.js Projects",
           width=800, height=400)

p.vbar(x='Library Name', top='Total_Usage', width=0.8, source=source)
p.xaxis.major_label_orientation = 45

show(p)
# Out:
#   <div id="bfbe0be6-fae7-414f-b02d-007358043500" data-root-id="p1159" style="display: contents;"></div>

# %% [markdown]
# ## Libraries with multiple versions

# %%
library_version_analysis = libraries_df.groupby('Library Name')['Library Version'].agg(['nunique', 'unique']).reset_index()
library_version_analysis.columns = ['Library', 'Version_Count', 'All_Versions']

# Libraries with multiple versions across projects
multi_versions = library_version_analysis[library_version_analysis['Version_Count'] > 1].sort_values('Version_Count', ascending=False)
print(multi_versions.head(10))
# Out:
#          Library  Version_Count  \
# 400         core             24
# 2127       types             17
# 2116   type-fest             15
# 339    commander             12
# 443        debug             11
# 1936  source-map             10
# 2274       yargs             10
# 768      globals             10
# 1878      semver              9
# 1341        node              9
#
#                                            All_Versions
# 400   [7.28.3, 0.2.9, 29.7.0, 7.26.7, 7.24.7, 2.1.6,...
# 2127  [7.28.4, 8.43.0, 6.21.0, 29.6.3, 7.26.7, 7.24....
# 2116  [0.18.1, 0.8.1, 0.20.2, 0.21.3, 0.6.0, 0.3.1, ...
# 339   [9.4.0, 2.15.1, 2.20.3, 8.3.0, 4.1.1, 2.3.0, 0...
# 443   [2.6.9, 4.4.1, 4.1.12, 3.2.7, 4.4.0, 2.2.0, 3....
# 1936  [0.6.1, 0.3.11, 29.6.3, 0.8.0-beta.0, 0.7.4, 0...
# 2274  [15.4.1, 17.7.2, 16.2.0, 17.0.33, 17.7.1, 17.0...
# 768   [13.24.0, 14.0.0, 29.7.0, 11.12.0, 8.39.1, 13....
# 1878  [6.3.1, 7.7.2, 5.7.2, 7.7.1, 7.6.2, 7.6.3, 7.7...
# 1341  [24.3.1, 16.18.126, 22.13.1, 18.15.3, 20.14.10...

# %% [markdown]
# ## Libraries with more vulnerabilities

# %%
# Merge the dataframes on library name and version
merged_df = libraries_df.merge(
    vulnerabilities_df,
    left_on=['Library Name', 'Library Version'],
    right_on=['name', 'version'],
    how='inner'
)

# Count CVEs per library (grouping by library name only)
cve_count = merged_df.groupby('Library Name').agg({
    'cve': 'count'
}).reset_index()

# Rename columns for clarity
cve_count.columns = ['Library Name', 'CVE Count']

# Step 3: Get top 10 unique libraries with most CVEs
top_10_libraries = cve_count.sort_values('CVE Count', ascending=False).head(10)

print(top_10_libraries.to_string(index=False))
# Out:
#    Library Name  CVE Count
# brace-expansion         93
#          lodash         61
#        electron         20
#        minimist         18
#          tar-fs          9
#             tmp          9
#             tar          7
#         request          5
#      handlebars          5
#       minimatch          4

# %% [markdown]
# ## Libraries organized by Severity

# %%
# Assuming you already have libraries_df and vulnerabilities_df loaded

# Merge the dataframes on library name and version
merged_df = libraries_df.merge(
    vulnerabilities_df,
    left_on=['Library Name', 'Library Version'],
    right_on=['name', 'version'],
    how='inner'
)

# Create severity pivot table with all possible severity levels
severity_pivot = merged_df.groupby(['Library Name', 'severity']).size().unstack(fill_value=0)

# Ensure all severity columns exist (add missing ones with 0 values)
severity_columns = ['CRITICAL', 'HIGH', 'LOW', 'MODERATE', 'UNKNOWN']
for col in severity_columns:
    if col not in severity_pivot.columns:
        severity_pivot[col] = 0

# Select and reorder columns
severity_pivot = severity_pivot[severity_columns]

# Calculate total column (sum of all severity counts)
severity_pivot['total'] = severity_pivot.sum(axis=1)

# Sort by total and get top 10
top_10_by_severity = severity_pivot.sort_values('total', ascending=False).head(10)

print(top_10_by_severity.to_string())
# Out:
# severity         CRITICAL  HIGH  LOW  MODERATE  UNKNOWN  total
# Library Name
# brace-expansion         0     0   93         0        0     93
# lodash                  3    35    0        23        0     61
# electron                1     6    3        10        0     20
# minimist                9     0    0         9        0     18
# handlebars              3     5    0         1        0      9
# tmp                     0     0    9         0        0      9
# tar-fs                  0     9    0         0        0      9
# tar                     0     6    0         1        0      7
# request                 0     0    0         5        0      5
# minimatch               0     4    0         0        0      4

# %% [markdown]
# ## Most used libraries by OSS projects with vulnerabilities

# %%
# Library analysis with vulnerability counts
library_analysis = libraries_df.groupby('Library Name').agg({
    'Project Name': ['count', 'nunique']
}).reset_index()

# Flatten column names
library_analysis.columns = ['Library Name', 'Total_Usage', 'Unique_Projects']

# Add vulnerability counts by merging with vulnerabilities_df
vuln_counts = vulnerabilities_df.groupby('name').size().reset_index(name='Vuln_Count')

# Merge library analysis with vulnerability counts
library_analysis = library_analysis.merge(
    vuln_counts,
    left_on='Library Name',
    right_on='name',
    how='left'
).drop('name', axis=1)

# Fill NaN values with 0 (libraries with no vulnerabilities)
library_analysis['Vuln_Count'] = library_analysis['Vuln_Count'].fillna(0).astype(int)

# Sort by total usage
library_analysis = library_analysis.sort_values('Unique_Projects', ascending=False)

print(library_analysis.head(10))
# Out:
#          Library Name  Total_Usage  Unique_Projects  Vuln_Count
# 443             debug           44               10           2
# 1184        lru-cache           35               10           0
# 760              glob           37               10           0
# 1284        minimatch           45               10           3
# 1317               ms           34               10           1
# 2257        wrap-ansi           30                9           0
# 1895  shebang-command            9                9           0
# 416       cross-spawn            9                9           2
# 988             isexe           18                9           0
# 1896    shebang-regex            9                9           0

# %% [markdown]
# ## OSS Projects with more vulnerabilities by severity

# %%
# Projects with vulnerabilities by severity
affected_projects = libraries_df.merge(
    vulnerabilities_df,
    left_on=['Library Name', 'Library Version'],
    right_on=['name', 'version'],
    how='inner'
)

# Count vulnerabilities by project and severity
project_vulns = affected_projects.groupby(['Project Name', 'severity'])['cve'].nunique().unstack(fill_value=0)

# Add total column
project_vulns['Total'] = project_vulns.sum(axis=1)

# Sort by total vulnerabilities
project_vulns = project_vulns.sort_values('Total', ascending=False)

print(project_vulns)
# Out:
# severity      CRITICAL  HIGH  LOW  MODERATE  UNKNOWN  Total
# Project Name
# lodash              13    34    3        19        0     69
# socket.io            1     9    8         4        0     22
# chalk                1     6    3        11        0     21
# passport             2     3    1         2        0      8
# mongoose             0     2    1         2        0      5
# axios                0     0    2         0        0      2
# bcrypt               0     1    1         0        0      2
# dotenv               0     0    1         1        0      2
# tailwindcss          0     0    0         0        0      0

# %% [markdown]
# ## Graph: Projects with vulnerabilities by severity

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource

# Enable Bokeh in Colab
output_notebook()

# Your data
affected_projects = libraries_df.merge(
    vulnerabilities_df,
    left_on=['Library Name', 'Library Version'],
    right_on=['name', 'version'],
    how='inner'
)

project_vulns = affected_projects.groupby(['Project Name', 'severity'])['cve'].nunique().unstack(fill_value=0)
project_vulns['Total'] = project_vulns.sum(axis=1)
project_vulns = project_vulns.sort_values('Total', ascending=False)

# Get top 10 projects
top_projects = project_vulns.head(10).reset_index()

# Create figure
p = figure(y_range=list(top_projects['Project Name']),
           title="Projects with Vulnerabilities by Severity",
           width=800, height=500)

# Get available severity columns
severity_cols = [col for col in top_projects.columns if col not in ['Project Name', 'Total']]
colors = ['red', 'orange', 'yellow', 'green', 'blue']

# Simple horizontal bars for each severity
for i, severity in enumerate(severity_cols):
    if severity in top_projects.columns:
        source = ColumnDataSource(top_projects)
        p.hbar(y='Project Name', right=severity, height=0.8,
               source=source, color=colors[i % len(colors)],
               legend_label=severity, alpha=0.7)

p.legend.location = "top_right"
p.xaxis.axis_label = "Number of Vulnerabilities"

show(p)
# Out:
#   <div id="c99f2323-018e-46e8-b250-0bbb7e432ada" data-root-id="p1424" style="display: contents;"></div>

# %% [markdown]
# ## Top licenses used by libraries

# %%
library_license_analysis = libraries_df.groupby('Library License').agg({
    'Library Name': ['count', 'nunique']
}).reset_index()

# Flatten column names
library_license_analysis.columns = ['Library Name', 'Total_Usage', 'Unique_Libraries']

# Sort by total usage
library_license_analysis = library_license_analysis.sort_values('Total_Usage', ascending=False)

print(library_license_analysis.head(17))
# Out:
#      Library Name  Total_Usage  Unique_Libraries
# 14            MIT         5735              1903
# 13            ISC          807               168
# 3      Apache-2.0          209                79
# 6    BSD-3-Clause          164                43
# 5    BSD-2-Clause          135                34
# 8   BlueOak-1.0.0           61                37
# 4             BSD           18                16
# 18     Python-2.0           10                 1
# 11        CC0-1.0            7                 2
# 10      CC-BY-4.0            7                 2
# 0            0BSD            6                 1
# 2      Apache 2.0            6                 4
# 9       CC-BY-3.0            6                 1
# 21          WTFPL            5                 5
# 20      Unlicense            4                 4
# 7        BSD-like            4                 3
# 15        MIT/X11            3                 3

# %% [markdown]
# ## Top Authors of libraries

# %%
library_author_analysis = libraries_df.groupby('Library Author').agg({
    'Library Name': ['count', 'nunique']
}).reset_index()

# Flatten column names
library_author_analysis.columns = ['Library Author Name', 'Total_Usage', 'Unique_Libraries']

# Sort by total usage
library_author_analysis = library_author_analysis.sort_values('Total_Usage', ascending=False)

print(library_author_analysis.head(10))
# Out:
#     Library Author Name  Total_Usage  Unique_Libraries
# 389       Sindre Sorhus         1249               223
# 174  Isaac Z. Schlueter          388                81
# 411      The Babel Team          345               112
# 222      Jordan Harband          231                99
# 151         GitHub Inc.          183                56
# 216      Jon Schlinkert          139                55
# 48              Ben Coe          111                14
# 425        Titus Wormer          102                62
# 405      TJ Holowaychuk           88                21
# 293      Mathias Bynens           87                14

# %% [markdown]
#  ## Libraries with missing author info

# %%
library_unknown_authors = libraries_df[libraries_df['Library Author'].isna()]
unknown_summary = library_unknown_authors.groupby('Library Name').agg({
    'Project Name': 'nunique',
    'Library Version': 'first'
}).rename(columns={'Project Name': 'Used_In_Projects', 'Library Version': 'Version'})
print(unknown_summary.sort_values('Used_In_Projects', ascending=False).head(20))
# Out:
#                     Used_In_Projects Version
# Library Name
# ms                                10   2.0.0
# inherits                           9   2.0.4
# argparse                           8  1.0.10
# chalk                              8   4.1.2
# source-map-support                 8  0.5.21
# yargs                              8  15.4.1
# error-ex                           8   1.3.2
# graceful-fs                        8  4.2.11
# fsevents                           8   2.3.3
# acorn                              8  8.15.0
# string_decoder                     7   1.1.1
# buffer-from                        7   1.1.2
# readable-stream                    7   3.6.2
# neo-async                          7   2.6.2
# node                               7  24.3.1
# estraverse                         7   4.3.0
# esutils                            7   2.0.3
# merge2                             6   1.4.1
# mime-types                         6  2.1.35
# commons                            6   3.0.1

# %% [markdown]
# ## Libraries with multiple versions and no author info

# %%
# Simple risky libraries summary
risky_analysis = libraries_df.groupby('Library Name').agg({
    'Library Version': 'nunique',
    'Library Author': lambda x: x.isna().sum()
}).rename(columns={
    'Library Version': 'Version_Count',
    'Library Author': 'No_Author_Count'
})

# Add vulnerability counts
vuln_counts = vulnerabilities_df.groupby('name').size().reset_index(name='Vuln_Count')
risky_analysis = risky_analysis.merge(vuln_counts, left_index=True, right_on='name', how='left')
risky_analysis['Vuln_Count'] = risky_analysis['Vuln_Count'].fillna(0).astype(int)
risky_analysis = risky_analysis.set_index('name')

# Sort by risk (multiple criteria)
risky_analysis = risky_analysis.sort_values(['Version_Count', 'Vuln_Count', 'No_Author_Count'], ascending=False)

print("Library Name | Versions | No Author | Vulnerabilities")
print(risky_analysis.head(20))
# Out:
# Library Name | Versions | No Author | Vulnerabilities
#                  Version_Count  No_Author_Count  Vuln_Count
# name
# core                        24                4           0
# types                       17               12           0
# type-fest                   15                0           0
# commander                   12                0           0
# debug                       11                5           2
# yargs                       10               21           0
# globals                     10                4           0
# source-map                  10                3           0
# semver                       9                4           1
# chalk                        9               45           0
# node                         9               22           0
# readable-stream              9               19           0
# glob                         9                1           0
# lru-cache                    9                0           0
# minimatch                    8                1           3
# yargs-parser                 8                4           1
# resolve                      8                1           0
# supports-color               8                1           0
# ansi-styles                  8                0           0
# typescript                   8                0           0

# %% [markdown]
# ## Generate a dataset with all libraries and version

# %%
# Export all libraries to CSV
all_libraries = libraries_df[['Library Name', 'Library Version']].drop_duplicates()

# Save to CSV
all_libraries.to_csv('all_libraries.csv', index=False)

print(f"Exported {len(all_libraries)} unique library-version combinations to 'all_libraries.csv'")
print("\nFirst 10 rows:")
print(all_libraries.head(10))
# Out:
# Exported 3870 unique library-version combinations to 'all_libraries.csv'
#
# First 10 rows:
#          Library Name Library Version
# 0                core          7.28.3
# 1          preset-env          7.28.3
# 2  mongodb-downloader           0.4.2
# 3       eslint-plugin          8.43.0
# 4              parser          8.43.0
# 5       acquit-ignore           0.2.1
# 6      acquit-require           0.1.1
# 7              acquit           1.4.0
# 8                 ajv          8.17.1
# 9   assert-browserify           2.0.0

# %% [markdown]
# ## Get the Current version of libraries

# %%
import pandas as pd
import requests
from packaging import version
import re

# Load your CSV
df = pd.read_csv('all_libraries.csv')

def clean_version(ver_string):
    """Clean version string to make it parseable"""
    if not ver_string or pd.isna(ver_string):
        return "0.0.0"

    ver_string = str(ver_string).strip()

    # Remove problematic suffixes
    ver_string = re.sub(r'-security.*', '', ver_string)
    ver_string = re.sub(r'-alpha.*', '', ver_string)
    ver_string = re.sub(r'-beta.*', '', ver_string)
    ver_string = re.sub(r'-rc.*', '', ver_string)
    ver_string = re.sub(r'-SNAPSHOT.*', '', ver_string)

    # Keep only digits and dots
    ver_string = re.sub(r'[^\d\.]', '', ver_string)

    # Ensure x.y.z format
    parts = ver_string.split('.')
    while len(parts) < 3:
        parts.append('0')

    return '.'.join(parts[:3])

def get_latest_npm_version(package_name):
    url = f'https://registry.npmjs.org/{package_name}'
    try:
        response = requests.get(url, timeout=10)
        if response.status_code == 200:
            data = response.json()
            return data.get("dist-tags", {}).get("latest")
    except:
        pass
    return None

def safe_version_compare(current_version, latest_version):
    if latest_version is None:
        return "Not Found"

    try:
        current_clean = clean_version(current_version)
        latest_clean = clean_version(latest_version)

        if version.parse(current_clean) < version.parse(latest_clean):
            return f"Update available ({latest_version})"
        elif version.parse(current_clean) == version.parse(latest_clean):
            return "Up-to-date"
        else:
            return f"Current version is newer than npm ({latest_version})"
    except:
        return "Version comparison failed"

# Check each library
results = []
for i, row in df.iterrows():
    package = row['Library Name']
    current_version = row['Library Version']

    print(f"Checking {i+1}/{len(df)}: {package}")

    latest_version = get_latest_npm_version(package)
    status = safe_version_compare(current_version, latest_version)

    results.append({
        "Library": package,
        "Current Version": current_version,
        "Latest Version": latest_version,
        "Status": status
    })

# Convert to DataFrame and display
results_df = pd.DataFrame(results)
print("\nResults:")
print(results_df)

# Save to CSV
results_df.to_csv("npm_version_check_results.csv", index=False)
print(f"\nSaved results to npm_version_check_results.csv")
# Out:
# Checking 1/3870: core
# Checking 2/3870: preset-env
# Checking 3/3870: mongodb-downloader
# Checking 4/3870: eslint-plugin
# Checking 5/3870: parser
# Checking 6/3870: acquit-ignore
# Checking 7/3870: acquit-require
# Checking 8/3870: acquit
# Checking 9/3870: ajv
# Checking 10/3870: assert-browserify
# Checking 11/3870: babel-loader
# Checking 12/3870: broken-link-checker
# Checking 13/3870: bson
# Checking 14/3870: buffer
# Checking 15/3870: cheerio
# Checking 16/3870: parse5
# Checking 17/3870: entities
# Checking 18/3870: crypto-browserify
# Checking 19/3870: dox
# Checking 20/3870: commander
# Checking 21/3870: eslint-plugin-markdown
# Checking 22/3870: eslint-plugin-mocha-no-only
# Checking 23/3870: eslint
# Checking 24/3870: ajv
# Checking 25/3870: chalk
# Checking 26/3870: escape-string-regexp
# Checking 27/3870: ignore
# Checking 28/3870: minimatch
# Checking 29/3870: strip-ansi
# Checking 30/3870: json-schema-traverse
# Checking 31/3870: ansi-styles
# Checking 32/3870: supports-color
# Checking 33/3870: brace-expansion
# Checking 34/3870: ansi-regex
# Checking 35/3870: express
# Checking 36/3870: debug
# Checking 37/3870: ms
# Checking 38/3870: fs-extra
# Checking 39/3870: highlight.js
# Checking 40/3870: kareem
# Checking 41/3870: lodash.isequal
# Checking 42/3870: lodash.isequalwith
# Checking 43/3870: markdownlint-cli2
# Checking 44/3870: markdown-it
# Checking 45/3870: linkify-it
# Checking 46/3870: mdurl
# Checking 47/3870: uc.micro
# Checking 48/3870: marked
# Checking 49/3870: mkdirp
# Checking 50/3870: mocha
# Checking 51/3870: supports-color
# Checking 52/3870: moment
# Checking 53/3870: mongodb-memory-server
# Checking 54/3870: mongodb-runner
# Checking 55/3870: mongodb
# Checking 56/3870: mpath
# Checking 57/3870: mquery
# Checking 58/3870: ms
# Checking 59/3870: ncp
# Checking 60/3870: nyc
# Checking 61/3870: convert-source-map
# Checking 62/3870: find-up
# Checking 63/3870: foreground-child
# Checking 64/3870: glob
# Checking 65/3870: resolve-from
# Checking 66/3870: signal-exit
# Checking 67/3870: yargs
# Checking 68/3870: locate-path
# Checking 69/3870: cliui
# Checking 70/3870: string-width
# Checking 71/3870: y18n
# Checking 72/3870: yargs-parser
# Checking 73/3870: p-locate
# Checking 74/3870: wrap-ansi
# Checking 75/3870: emoji-regex
# Checking 76/3870: camelcase
# Checking 77/3870: p-limit
# Checking 78/3870: pug
# Checking 79/3870: q
# Checking 80/3870: sift
# Checking 81/3870: sinon
# Checking 82/3870: stream-browserify
# Checking 83/3870: readable-stream
# Checking 84/3870: tsd
# Checking 85/3870: globby
# Checking 86/3870: slash
# Checking 87/3870: typescript
# Checking 88/3870: uuid
# Checking 89/3870: webpack
# Checking 90/3870: eslint-scope
# Checking 91/3870: schema-utils
# Checking 92/3870: estraverse
# Checking 93/3870: remapping
# Checking 94/3870: code-frame
# Checking 95/3870: generator
# Checking 96/3870: helper-compilation-targets
# Checking 97/3870: helper-module-transforms
# Checking 98/3870: helpers
# Checking 99/3870: parser
# Checking 100/3870: template
# Checking 101/3870: traverse
# Checking 102/3870: types
# Checking 103/3870: convert-source-map
# Checking 104/3870: debug
# Checking 105/3870: gensync
# Checking 106/3870: json5
# Checking 107/3870: semver
# Checking 108/3870: compat-data
# Checking 109/3870: helper-plugin-utils
# Checking 110/3870: helper-validator-option
# Checking 111/3870: plugin-bugfix-firefox-class-in-computed-class-key
# Checking 112/3870: plugin-bugfix-safari-class-field-initializer-scope
# Checking 113/3870: plugin-bugfix-safari-id-destructuring-collision-in-function-expression
# Checking 114/3870: plugin-bugfix-v8-spread-parameters-in-optional-chaining
# Checking 115/3870: plugin-bugfix-v8-static-class-fields-redefine-readonly
# Checking 116/3870: plugin-proposal-private-property-in-object
# Checking 117/3870: plugin-syntax-import-assertions
# Checking 118/3870: plugin-syntax-import-attributes
# Checking 119/3870: plugin-syntax-unicode-sets-regex
# Checking 120/3870: plugin-transform-arrow-functions
# Checking 121/3870: plugin-transform-async-generator-functions
# Checking 122/3870: plugin-transform-async-to-generator
# Checking 123/3870: plugin-transform-block-scoped-functions
# Checking 124/3870: plugin-transform-block-scoping
# Checking 125/3870: plugin-transform-class-properties
# Checking 126/3870: plugin-transform-class-static-block
# Checking 127/3870: plugin-transform-classes
# Checking 128/3870: plugin-transform-computed-properties
# Checking 129/3870: plugin-transform-destructuring
# Checking 130/3870: plugin-transform-dotall-regex
# Checking 131/3870: plugin-transform-duplicate-keys
# Checking 132/3870: plugin-transform-duplicate-named-capturing-groups-regex
# Checking 133/3870: plugin-transform-dynamic-import
# Checking 134/3870: plugin-transform-explicit-resource-management
# Checking 135/3870: plugin-transform-exponentiation-operator
# Checking 136/3870: plugin-transform-export-namespace-from
# Checking 137/3870: plugin-transform-for-of
# Checking 138/3870: plugin-transform-function-name
# Checking 139/3870: plugin-transform-json-strings
# Checking 140/3870: plugin-transform-literals
# Checking 141/3870: plugin-transform-logical-assignment-operators
# Checking 142/3870: plugin-transform-member-expression-literals
# Checking 143/3870: plugin-transform-modules-amd
# Checking 144/3870: plugin-transform-modules-commonjs
# Checking 145/3870: plugin-transform-modules-systemjs
# Checking 146/3870: plugin-transform-modules-umd
# Checking 147/3870: plugin-transform-named-capturing-groups-regex
# Checking 148/3870: plugin-transform-new-target
# Checking 149/3870: plugin-transform-nullish-coalescing-operator
# Checking 150/3870: plugin-transform-numeric-separator
# Checking 151/3870: plugin-transform-object-rest-spread
# Checking 152/3870: plugin-transform-object-super
# Checking 153/3870: plugin-transform-optional-catch-binding
# Checking 154/3870: plugin-transform-optional-chaining
# Checking 155/3870: plugin-transform-parameters
# Checking 156/3870: plugin-transform-private-methods
# Checking 157/3870: plugin-transform-private-property-in-object
# Checking 158/3870: plugin-transform-property-literals
# Checking 159/3870: plugin-transform-regenerator
# Checking 160/3870: plugin-transform-regexp-modifiers
# Checking 161/3870: plugin-transform-reserved-words
# Checking 162/3870: plugin-transform-shorthand-properties
# Checking 163/3870: plugin-transform-spread
# Checking 164/3870: plugin-transform-sticky-regex
# Checking 165/3870: plugin-transform-template-literals
# Checking 166/3870: plugin-transform-typeof-symbol
# Checking 167/3870: plugin-transform-unicode-escapes
# Checking 168/3870: plugin-transform-unicode-property-regex
# Checking 169/3870: plugin-transform-unicode-regex
# Checking 170/3870: plugin-transform-unicode-sets-regex
# Checking 171/3870: preset-modules
# Checking 172/3870: babel-plugin-polyfill-corejs2
# Checking 173/3870: babel-plugin-polyfill-corejs3
# Checking 174/3870: babel-plugin-polyfill-regenerator
# Checking 175/3870: core-js-compat
# Checking 176/3870: decompress
# Checking 177/3870: make-dir
# Checking 178/3870: pify
# Checking 179/3870: mongodb-download-url
# Checking 180/3870: semver
# Checking 181/3870: node-fetch
# Checking 182/3870: whatwg-url
# Checking 183/3870: tr46
# Checking 184/3870: webidl-conversions
# Checking 185/3870: tar
# Checking 186/3870: minipass
# Checking 187/3870: mkdirp
# Checking 188/3870: yallist
# Checking 189/3870: regexpp
# Checking 190/3870: scope-manager
# Checking 191/3870: type-utils
# Checking 192/3870: utils
# Checking 193/3870: visitor-keys
# Checking 194/3870: eslint-visitor-keys
# Checking 195/3870: graphemer
# Checking 196/3870: ignore
# Checking 197/3870: natural-compare
# Checking 198/3870: ts-api-utils
# Checking 199/3870: types
# Checking 200/3870: typescript-estree
# Checking 201/3870: archetype
# Checking 202/3870: mpath
# Checking 203/3870: commander
# Checking 204/3870: espree
# Checking 205/3870: fast-deep-equal
# Checking 206/3870: fast-uri
# Checking 207/3870: json-schema-traverse
# Checking 208/3870: require-from-string
# Checking 209/3870: es6-object-assign
# Checking 210/3870: is-nan
# Checking 211/3870: object-is
# Checking 212/3870: util
# Checking 213/3870: find-cache-dir
# Checking 214/3870: loader-utils
# Checking 215/3870: make-dir
# Checking 216/3870: schema-utils
# Checking 217/3870: ajv-keywords
# Checking 218/3870: bhttp
# Checking 219/3870: extend
# Checking 220/3870: calmcard
# Checking 221/3870: chalk
# Checking 222/3870: char-spinner
# Checking 223/3870: condense-whitespace
# Checking 224/3870: default-user-agent
# Checking 225/3870: errno
# Checking 226/3870: extend
# Checking 227/3870: http-equiv-refresh
# Checking 228/3870: humanize-duration
# Checking 229/3870: is-stream
# Checking 230/3870: is-string
# Checking 231/3870: limited-request-queue
# Checking 232/3870: link-types
# Checking 233/3870: maybe-callback
# Checking 234/3870: nopter
# Checking 235/3870: camelcase
# Checking 236/3870: chalk
# Checking 237/3870: object-assign
# Checking 238/3870: ansi-styles
# Checking 239/3870: has-ansi
# Checking 240/3870: strip-ansi
# Checking 241/3870: supports-color
# Checking 242/3870: ansi-regex
# Checking 243/3870: parse5
# Checking 244/3870: robot-directives
# Checking 245/3870: robots-txt-guard
# Checking 246/3870: robots-txt-parse
# Checking 247/3870: urlcache
# Checking 248/3870: urlobj
# Checking 249/3870: base64-js
# Checking 250/3870: ieee754
# Checking 251/3870: cheerio-select
# Checking 252/3870: dom-serializer
# Checking 253/3870: domhandler
# Checking 254/3870: domutils
# Checking 255/3870: encoding-sniffer
# Checking 256/3870: htmlparser2
# Checking 257/3870: parse5-htmlparser2-tree-adapter
# Checking 258/3870: parse5-parser-stream
# Checking 259/3870: undici
# Checking 260/3870: whatwg-mimetype
# Checking 261/3870: browserify-cipher
# Checking 262/3870: browserify-sign
# Checking 263/3870: create-ecdh
# Checking 264/3870: bn.js
# Checking 265/3870: create-hash
# Checking 266/3870: create-hmac
# Checking 267/3870: diffie-hellman
# Checking 268/3870: hash-base
# Checking 269/3870: inherits
# Checking 270/3870: pbkdf2
# Checking 271/3870: create-hash
# Checking 272/3870: ripemd160
# Checking 273/3870: hash-base
# Checking 274/3870: public-encrypt
# Checking 275/3870: randombytes
# Checking 276/3870: randomfill
# Checking 277/3870: jsdoctypeparser
# Checking 278/3870: markdown-it
# Checking 279/3870: entities
# Checking 280/3870: mdast-util-from-markdown
# Checking 281/3870: micromark
# Checking 282/3870: requireindex
# Checking 283/3870: eslint-utils
# Checking 284/3870: eslintrc
# Checking 285/3870: js
# Checking 286/3870: config-array
# Checking 287/3870: module-importer
# Checking 288/3870: fs.walk
# Checking 289/3870: structured-clone
# Checking 290/3870: cross-spawn
# Checking 291/3870: doctrine
# Checking 292/3870: eslint-scope
# Checking 293/3870: eslint-visitor-keys
# Checking 294/3870: esquery
# Checking 295/3870: esutils
# Checking 296/3870: file-entry-cache
# Checking 297/3870: find-up
# Checking 298/3870: glob-parent
# Checking 299/3870: globals
# Checking 300/3870: imurmurhash
# Checking 301/3870: is-glob
# Checking 302/3870: is-path-inside
# Checking 303/3870: js-yaml
# Checking 304/3870: json-stable-stringify-without-jsonify
# Checking 305/3870: levn
# Checking 306/3870: lodash.merge
# Checking 307/3870: optionator
# Checking 308/3870: text-table
# Checking 309/3870: accepts
# Checking 310/3870: array-flatten
# Checking 311/3870: body-parser
# Checking 312/3870: iconv-lite
# Checking 313/3870: content-disposition
# Checking 314/3870: content-type
# Checking 315/3870: cookie-signature
# Checking 316/3870: cookie
# Checking 317/3870: depd
# Checking 318/3870: encodeurl
# Checking 319/3870: escape-html
# Checking 320/3870: etag
# Checking 321/3870: finalhandler
# Checking 322/3870: fresh
# Checking 323/3870: http-errors
# Checking 324/3870: merge-descriptors
# Checking 325/3870: methods
# Checking 326/3870: on-finished
# Checking 327/3870: parseurl
# Checking 328/3870: path-to-regexp
# Checking 329/3870: proxy-addr
# Checking 330/3870: qs
# Checking 331/3870: range-parser
# Checking 332/3870: safe-buffer
# Checking 333/3870: send
# Checking 334/3870: encodeurl
# Checking 335/3870: serve-static
# Checking 336/3870: setprototypeof
# Checking 337/3870: statuses
# Checking 338/3870: type-is
# Checking 339/3870: utils-merge
# Checking 340/3870: vary
# Checking 341/3870: graceful-fs
# Checking 342/3870: jsonfile
# Checking 343/3870: universalify
# Checking 344/3870: globby
# Checking 345/3870: jsonc-parser
# Checking 346/3870: markdownlint-cli2-formatter-default
# Checking 347/3870: markdownlint
# Checking 348/3870: micromatch
# Checking 349/3870: browser-stdout
# Checking 350/3870: chokidar
# Checking 351/3870: diff
# Checking 352/3870: glob
# Checking 353/3870: he
# Checking 354/3870: log-symbols
# Checking 355/3870: minimatch
# Checking 356/3870: picocolors
# Checking 357/3870: serialize-javascript
# Checking 358/3870: strip-json-comments
# Checking 359/3870: workerpool
# Checking 360/3870: yargs-parser
# Checking 361/3870: yargs-unparser
# Checking 362/3870: decamelize
# Checking 363/3870: is-plain-obj
# Checking 364/3870: yargs
# Checking 365/3870: mongodb-memory-server-core
# Checking 366/3870: tar-stream
# Checking 367/3870: yauzl
# Checking 368/3870: tslib
# Checking 369/3870: saslprep
# Checking 370/3870: mongodb-connection-string-url
# Checking 371/3870: load-nyc-config
# Checking 372/3870: js-yaml
# Checking 373/3870: argparse
# Checking 374/3870: schema
# Checking 375/3870: caching-transform
# Checking 376/3870: decamelize
# Checking 377/3870: get-package-type
# Checking 378/3870: istanbul-lib-coverage
# Checking 379/3870: istanbul-lib-hook
# Checking 380/3870: istanbul-lib-instrument
# Checking 381/3870: istanbul-lib-processinfo
# Checking 382/3870: uuid
# Checking 383/3870: istanbul-lib-report
# Checking 384/3870: make-dir
# Checking 385/3870: istanbul-lib-source-maps
# Checking 386/3870: istanbul-reports
# Checking 387/3870: node-preload
# Checking 388/3870: p-map
# Checking 389/3870: process-on-spawn
# Checking 390/3870: rimraf
# Checking 391/3870: spawn-wrap
# Checking 392/3870: test-exclude
# Checking 393/3870: pug-code-gen
# Checking 394/3870: pug-filters
# Checking 395/3870: pug-lexer
# Checking 396/3870: pug-linker
# Checking 397/3870: pug-load
# Checking 398/3870: pug-parser
# Checking 399/3870: pug-runtime
# Checking 400/3870: pug-strip-comments
# Checking 401/3870: commons
# Checking 402/3870: fake-timers
# Checking 403/3870: samsam
# Checking 404/3870: type-detect
# Checking 405/3870: eslint-formatter-pretty
# Checking 406/3870: jest-diff
# Checking 407/3870: meow
# Checking 408/3870: type-fest
# Checking 409/3870: yargs-parser
# Checking 410/3870: path-exists
# Checking 411/3870: read-pkg-up
# Checking 412/3870: type-fest
# Checking 413/3870: eslint-scope
# Checking 414/3870: estree
# Checking 415/3870: json-schema
# Checking 416/3870: ast
# Checking 417/3870: wasm-edit
# Checking 418/3870: wasm-parser
# Checking 419/3870: acorn-import-phases
# Checking 420/3870: acorn
# Checking 421/3870: browserslist
# Checking 422/3870: chrome-trace-event
# Checking 423/3870: enhanced-resolve
# Checking 424/3870: es-module-lexer
# Checking 425/3870: events
# Checking 426/3870: glob-to-regexp
# Checking 427/3870: json-parse-even-better-errors
# Checking 428/3870: loader-runner
# Checking 429/3870: mime-types
# Checking 430/3870: neo-async
# Checking 431/3870: tapable
# Checking 432/3870: terser-webpack-plugin
# Checking 433/3870: watchpack
# Checking 434/3870: webpack-sources
# Checking 435/3870: gen-mapping
# Checking 436/3870: trace-mapping
# Checking 437/3870: helper-validator-identifier
# Checking 438/3870: js-tokens
# Checking 439/3870: jsesc
# Checking 440/3870: lru-cache
# Checking 441/3870: helper-module-imports
# Checking 442/3870: helper-globals
# Checking 443/3870: helper-string-parser
# Checking 444/3870: helper-skip-transparent-expression-wrappers
# Checking 445/3870: helper-create-regexp-features-plugin
# Checking 446/3870: helper-remap-async-to-generator
# Checking 447/3870: helper-create-class-features-plugin
# Checking 448/3870: helper-annotate-as-pure
# Checking 449/3870: helper-replace-supers
# Checking 450/3870: helper-define-polyfill-provider
# Checking 451/3870: decompress-tar
# Checking 452/3870: decompress-tarbz2
# Checking 453/3870: file-type
# Checking 454/3870: decompress-targz
# Checking 455/3870: decompress-unzip
# Checking 456/3870: file-type
# Checking 457/3870: pify
# Checking 458/3870: strip-dirs
# Checking 459/3870: minimist
# Checking 460/3870: chownr
# Checking 461/3870: fs-minipass
# Checking 462/3870: minipass
# Checking 463/3870: minizlib
# Checking 464/3870: project-service
# Checking 465/3870: tsconfig-utils
# Checking 466/3870: fast-glob
# Checking 467/3870: glob-parent
# Checking 468/3870: lodash.clonedeep
# Checking 469/3870: lodash.set
# Checking 470/3870: acorn-jsx
# Checking 471/3870: call-bind
# Checking 472/3870: define-properties
# Checking 473/3870: is-arguments
# Checking 474/3870: is-generator-function
# Checking 475/3870: is-typed-array
# Checking 476/3870: which-typed-array
# Checking 477/3870: commondir
# Checking 478/3870: pkg-dir
# Checking 479/3870: big.js
# Checking 480/3870: emojis-list
# Checking 481/3870: bluebird
# Checking 482/3870: concat-stream
# Checking 483/3870: dev-null
# Checking 484/3870: errors
# Checking 485/3870: form-data2
# Checking 486/3870: uuid
# Checking 487/3870: form-fix-array
# Checking 488/3870: stream-length
# Checking 489/3870: through2-sink
# Checking 490/3870: xtend
# Checking 491/3870: through2-spy
# Checking 492/3870: tough-cookie
# Checking 493/3870: ansi-styles
# Checking 494/3870: escape-string-regexp
# Checking 495/3870: has-ansi
# Checking 496/3870: strip-ansi
# Checking 497/3870: supports-color
# Checking 498/3870: os-name
# Checking 499/3870: prr
# Checking 500/3870: call-bound
# Checking 501/3870: has-tostringtag
# Checking 502/3870: is-browser
# Checking 503/3870: parse-domain
# Checking 504/3870: caller-path
# Checking 505/3870: cli-table
# Checking 506/3870: eol
# Checking 507/3870: nopt
# Checking 508/3870: splitargs
# Checking 509/3870: node
# Checking 510/3870: isbot
# Checking 511/3870: useragent
# Checking 512/3870: lru-cache
# Checking 513/3870: yallist
# Checking 514/3870: split
# Checking 515/3870: stream-combiner
# Checking 516/3870: through
# Checking 517/3870: is-object
# Checking 518/3870: object-assign
# Checking 519/3870: boolbase
# Checking 520/3870: css-select
# Checking 521/3870: css-what
# Checking 522/3870: domelementtype
# Checking 523/3870: entities
# Checking 524/3870: iconv-lite
# Checking 525/3870: whatwg-encoding
# Checking 526/3870: browserify-aes
# Checking 527/3870: browserify-des
# Checking 528/3870: evp_bytestokey
# Checking 529/3870: bn.js
# Checking 530/3870: browserify-rsa
# Checking 531/3870: elliptic
# Checking 532/3870: parse-asn1
# Checking 533/3870: readable-stream
# Checking 534/3870: safe-buffer
# Checking 535/3870: cipher-base
# Checking 536/3870: md5.js
# Checking 537/3870: ripemd160
# Checking 538/3870: sha.js
# Checking 539/3870: miller-rabin
# Checking 540/3870: to-buffer
# Checking 541/3870: isarray
# Checking 542/3870: argparse
# Checking 543/3870: linkify-it
# Checking 544/3870: mdurl
# Checking 545/3870: uc.micro
# Checking 546/3870: mdast
# Checking 547/3870: mdast-util-to-string
# Checking 548/3870: parse-entities
# Checking 549/3870: character-entities
# Checking 550/3870: unist-util-stringify-position
# Checking 551/3870: import-fresh
# Checking 552/3870: object-schema
# Checking 553/3870: fs.scandir
# Checking 554/3870: fastq
# Checking 555/3870: fast-json-stable-stringify
# Checking 556/3870: uri-js
# Checking 557/3870: path-key
# Checking 558/3870: shebang-command
# Checking 559/3870: which
# Checking 560/3870: esrecurse
# Checking 561/3870: estraverse
# Checking 562/3870: flat-cache
# Checking 563/3870: locate-path
# Checking 564/3870: type-fest
# Checking 565/3870: is-extglob
# Checking 566/3870: prelude-ls
# Checking 567/3870: type-check
# Checking 568/3870: deep-is
# Checking 569/3870: fast-levenshtein
# Checking 570/3870: word-wrap
# Checking 571/3870: negotiator
# Checking 572/3870: bytes
# Checking 573/3870: destroy
# Checking 574/3870: raw-body
# Checking 575/3870: unpipe
# Checking 576/3870: toidentifier
# Checking 577/3870: ee-first
# Checking 578/3870: forwarded
# Checking 579/3870: ipaddr.js
# Checking 580/3870: side-channel
# Checking 581/3870: mime
# Checking 582/3870: media-typer
# Checking 583/3870: merge-streams
# Checking 584/3870: path-type
# Checking 585/3870: slash
# Checking 586/3870: unicorn-magic
# Checking 587/3870: punycode.js
# Checking 588/3870: micromark-core-commonmark
# Checking 589/3870: micromark-extension-directive
# Checking 590/3870: parse-entities
# Checking 591/3870: character-entities-legacy
# Checking 592/3870: character-reference-invalid
# Checking 593/3870: is-alphanumerical
# Checking 594/3870: is-decimal
# Checking 595/3870: is-hexadecimal
# Checking 596/3870: is-alphabetical
# Checking 597/3870: micromark-extension-gfm-autolink-literal
# Checking 598/3870: micromark-extension-gfm-footnote
# Checking 599/3870: micromark-extension-gfm-table
# Checking 600/3870: micromark-extension-math
# Checking 601/3870: micromark-util-types
# Checking 602/3870: micromark
# Checking 603/3870: braces
# Checking 604/3870: picomatch
# Checking 605/3870: readdirp
# Checking 606/3870: foreground-child
# Checking 607/3870: jackspeak
# Checking 608/3870: minipass
# Checking 609/3870: package-json-from-dist
# Checking 610/3870: path-scurry
# Checking 611/3870: lru-cache
# Checking 612/3870: is-unicode-supported
# Checking 613/3870: brace-expansion
# Checking 614/3870: has-flag
# Checking 615/3870: camelcase
# Checking 616/3870: flat
# Checking 617/3870: cliui
# Checking 618/3870: wrap-ansi
# Checking 619/3870: escalade
# Checking 620/3870: get-caller-file
# Checking 621/3870: require-directory
# Checking 622/3870: y18n
# Checking 623/3870: async-mutex
# Checking 624/3870: follow-redirects
# Checking 625/3870: https-proxy-agent
# Checking 626/3870: new-find-package-json
# Checking 627/3870: sparse-bitfield
# Checking 628/3870: whatwg-url
# Checking 629/3870: whatwg-url
# Checking 630/3870: hasha
# Checking 631/3870: is-stream
# Checking 632/3870: package-hash
# Checking 633/3870: write-file-atomic
# Checking 634/3870: fs.realpath
# Checking 635/3870: inflight
# Checking 636/3870: once
# Checking 637/3870: path-is-absolute
# Checking 638/3870: append-transform
# Checking 639/3870: archy
# Checking 640/3870: source-map
# Checking 641/3870: html-escaper
# Checking 642/3870: aggregate-error
# Checking 643/3870: fromentries
# Checking 644/3870: is-windows
# Checking 645/3870: require-main-filename
# Checking 646/3870: set-blocking
# Checking 647/3870: which-module
# Checking 648/3870: constantinople
# Checking 649/3870: doctypes
# Checking 650/3870: js-stringify
# Checking 651/3870: pug-attrs
# Checking 652/3870: pug-error
# Checking 653/3870: void-elements
# Checking 654/3870: with
# Checking 655/3870: jstransformer
# Checking 656/3870: pug-walk
# Checking 657/3870: resolve
# Checking 658/3870: character-parser
# Checking 659/3870: is-expression
# Checking 660/3870: acorn
# Checking 661/3870: token-stream
# Checking 662/3870: type-detect
# Checking 663/3870: string_decoder
# Checking 664/3870: util-deprecate
# Checking 665/3870: eslint
# Checking 666/3870: ansi-escapes
# Checking 667/3870: type-fest
# Checking 668/3870: eslint-rule-docs
# Checking 669/3870: plur
# Checking 670/3870: supports-hyperlinks
# Checking 671/3870: array-union
# Checking 672/3870: dir-glob
# Checking 673/3870: path-type
# Checking 674/3870: merge2
# Checking 675/3870: diff-sequences
# Checking 676/3870: jest-get-type
# Checking 677/3870: pretty-format
# Checking 678/3870: ansi-styles
# Checking 679/3870: minimist
# Checking 680/3870: camelcase-keys
# Checking 681/3870: decamelize-keys
# Checking 682/3870: map-obj
# Checking 683/3870: hard-rejection
# Checking 684/3870: minimist-options
# Checking 685/3870: normalize-package-data
# Checking 686/3870: redent
# Checking 687/3870: trim-newlines
# Checking 688/3870: read-pkg
# Checking 689/3870: normalize-package-data
# Checking 690/3870: type-fest
# Checking 691/3870: hosted-git-info
# Checking 692/3870: semver
# Checking 693/3870: helper-numbers
# Checking 694/3870: helper-wasm-bytecode
# Checking 695/3870: helper-buffer
# Checking 696/3870: helper-wasm-section
# Checking 697/3870: wasm-gen
# Checking 698/3870: wasm-opt
# Checking 699/3870: wast-printer
# Checking 700/3870: helper-api-error
# Checking 701/3870: ieee754
# Checking 702/3870: leb128
# Checking 703/3870: utf8
# Checking 704/3870: caniuse-lite
# Checking 705/3870: electron-to-chromium
# Checking 706/3870: node-releases
# Checking 707/3870: update-browserslist-db
# Checking 708/3870: mime-db
# Checking 709/3870: ajv-formats
# Checking 710/3870: ajv-keywords
# Checking 711/3870: jest-worker
# Checking 712/3870: terser
# Checking 713/3870: commander
# Checking 714/3870: sourcemap-codec
# Checking 715/3870: resolve-uri
# Checking 716/3870: yallist
# Checking 717/3870: regexpu-core
# Checking 718/3870: helper-wrap-function
# Checking 719/3870: helper-member-expression-to-functions
# Checking 720/3870: helper-optimise-call-expression
# Checking 721/3870: lodash.debounce
# Checking 722/3870: file-type
# Checking 723/3870: tar-stream
# Checking 724/3870: seek-bzip
# Checking 725/3870: unbzip2-stream
# Checking 726/3870: get-stream
# Checking 727/3870: yauzl
# Checking 728/3870: is-natural-number
# Checking 729/3870: fs.stat
# Checking 730/3870: call-bind-apply-helpers
# Checking 731/3870: es-define-property
# Checking 732/3870: get-intrinsic
# Checking 733/3870: set-function-length
# Checking 734/3870: define-data-property
# Checking 735/3870: has-property-descriptors
# Checking 736/3870: object-keys
# Checking 737/3870: get-proto
# Checking 738/3870: safe-regex-test
# Checking 739/3870: available-typed-arrays
# Checking 740/3870: for-each
# Checking 741/3870: gopd
# Checking 742/3870: buffer-from
# Checking 743/3870: typedarray
# Checking 744/3870: combined-stream2
# Checking 745/3870: through2
# Checking 746/3870: readable-stream
# Checking 747/3870: isarray
# Checking 748/3870: string_decoder
# Checking 749/3870: psl
# Checking 750/3870: punycode
# Checking 751/3870: ansi-regex
# Checking 752/3870: osx-release
# Checking 753/3870: win-release
# Checking 754/3870: has-symbols
# Checking 755/3870: callsites
# Checking 756/3870: colors
# Checking 757/3870: abbrev
# Checking 758/3870: undici-types
# Checking 759/3870: tmp
# Checking 760/3870: duplexer
# Checking 761/3870: nth-check
# Checking 762/3870: safer-buffer
# Checking 763/3870: buffer-xor
# Checking 764/3870: des.js
# Checking 765/3870: brorand
# Checking 766/3870: hash.js
# Checking 767/3870: hmac-drbg
# Checking 768/3870: minimalistic-assert
# Checking 769/3870: minimalistic-crypto-utils
# Checking 770/3870: asn1.js
# Checking 771/3870: core-util-is
# Checking 772/3870: isarray
# Checking 773/3870: process-nextick-args
# Checking 774/3870: typed-array-buffer
# Checking 775/3870: unist
# Checking 776/3870: character-entities-legacy
# Checking 777/3870: character-reference-invalid
# Checking 778/3870: is-alphanumerical
# Checking 779/3870: is-decimal
# Checking 780/3870: is-hexadecimal
# Checking 781/3870: parent-module
# Checking 782/3870: callsites
# Checking 783/3870: resolve-from
# Checking 784/3870: run-parallel
# Checking 785/3870: reusify
# Checking 786/3870: color-convert
# Checking 787/3870: shebang-regex
# Checking 788/3870: isexe
# Checking 789/3870: flatted
# Checking 790/3870: keyv
# Checking 791/3870: p-locate
# Checking 792/3870: balanced-match
# Checking 793/3870: concat-map
# Checking 794/3870: es-errors
# Checking 795/3870: object-inspect
# Checking 796/3870: side-channel-list
# Checking 797/3870: side-channel-map
# Checking 798/3870: side-channel-weakmap
# Checking 799/3870: decode-named-character-reference
# Checking 800/3870: devlop
# Checking 801/3870: micromark-factory-destination
# Checking 802/3870: micromark-factory-label
# Checking 803/3870: micromark-factory-space
# Checking 804/3870: micromark-factory-title
# Checking 805/3870: micromark-factory-whitespace
# Checking 806/3870: micromark-util-character
# Checking 807/3870: micromark-util-chunked
# Checking 808/3870: micromark-util-classify-character
# Checking 809/3870: micromark-util-html-tag-name
# Checking 810/3870: micromark-util-normalize-identifier
# Checking 811/3870: micromark-util-resolve-all
# Checking 812/3870: micromark-util-subtokenize
# Checking 813/3870: micromark-util-symbol
# Checking 814/3870: micromark-util-sanitize-uri
# Checking 815/3870: katex
# Checking 816/3870: katex
# Checking 817/3870: commander
# Checking 818/3870: debug
# Checking 819/3870: micromark-util-combine-extensions
# Checking 820/3870: micromark-util-decode-numeric-character-reference
# Checking 821/3870: micromark-util-encode
# Checking 822/3870: fill-range
# Checking 823/3870: signal-exit
# Checking 824/3870: cliui
# Checking 825/3870: strip-ansi
# Checking 826/3870: ansi-regex
# Checking 827/3870: parseargs
# Checking 828/3870: is-fullwidth-code-point
# Checking 829/3870: agent-base
# Checking 830/3870: b4a
# Checking 831/3870: fast-fifo
# Checking 832/3870: streamx
# Checking 833/3870: buffer-crc32
# Checking 834/3870: pend
# Checking 835/3870: memory-pager
# Checking 836/3870: webidl-conversions
# Checking 837/3870: tr46
# Checking 838/3870: webidl-conversions
# Checking 839/3870: esprima
# Checking 840/3870: lodash.flattendeep
# Checking 841/3870: release-zalgo
# Checking 842/3870: is-typedarray
# Checking 843/3870: typedarray-to-buffer
# Checking 844/3870: wrappy
# Checking 845/3870: default-require-extensions
# Checking 846/3870: clean-stack
# Checking 847/3870: indent-string
# Checking 848/3870: assert-never
# Checking 849/3870: babel-walk
# Checking 850/3870: is-promise
# Checking 851/3870: promise
# Checking 852/3870: is-core-module
# Checking 853/3870: path-parse
# Checking 854/3870: supports-preserve-symlinks-flag
# Checking 855/3870: is-regex
# Checking 856/3870: irregular-plurals
# Checking 857/3870: schemas
# Checking 858/3870: react-is
# Checking 859/3870: map-obj
# Checking 860/3870: quick-lru
# Checking 861/3870: arrify
# Checking 862/3870: is-plain-obj
# Checking 863/3870: kind-of
# Checking 864/3870: hosted-git-info
# Checking 865/3870: lru-cache
# Checking 866/3870: validate-npm-package-license
# Checking 867/3870: strip-indent
# Checking 868/3870: normalize-package-data
# Checking 869/3870: parse-json
# Checking 870/3870: floating-point-hex-parser
# Checking 871/3870: long
# Checking 872/3870: ieee754
# Checking 873/3870: merge-stream
# Checking 874/3870: source-map
# Checking 875/3870: source-map-support
# Checking 876/3870: regenerate-unicode-properties
# Checking 877/3870: regenerate
# Checking 878/3870: regjsgen
# Checking 879/3870: regjsparser
# Checking 880/3870: jsesc
# Checking 881/3870: unicode-match-property-ecmascript
# Checking 882/3870: unicode-match-property-value-ecmascript
# Checking 883/3870: bl
# Checking 884/3870: buffer-alloc
# Checking 885/3870: end-of-stream
# Checking 886/3870: fs-constants
# Checking 887/3870: xtend
# Checking 888/3870: pinkie-promise
# Checking 889/3870: fd-slicer
# Checking 890/3870: function-bind
# Checking 891/3870: es-object-atoms
# Checking 892/3870: hasown
# Checking 893/3870: math-intrinsics
# Checking 894/3870: dunder-proto
# Checking 895/3870: possible-typed-array-names
# Checking 896/3870: is-callable
# Checking 897/3870: pseudomap
# Checking 898/3870: os-tmpdir
# Checking 899/3870: is-alphabetical
# Checking 900/3870: queue-microtask
# Checking 901/3870: color-name
# Checking 902/3870: json-buffer
# Checking 903/3870: p-limit
# Checking 904/3870: character-entities
# Checking 905/3870: dequal
# Checking 906/3870: ms
# Checking 907/3870: to-regex-range
# Checking 908/3870: string-width
# Checking 909/3870: wrap-ansi
# Checking 910/3870: ansi-styles
# Checking 911/3870: bare-events
# Checking 912/3870: text-decoder
# Checking 913/3870: sprintf-js
# Checking 914/3870: es6-error
# Checking 915/3870: strip-bom
# Checking 916/3870: asap
# Checking 917/3870: typebox
# Checking 918/3870: spdx-correct
# Checking 919/3870: spdx-expression-parse
# Checking 920/3870: min-indent
# Checking 921/3870: error-ex
# Checking 922/3870: lines-and-columns
# Checking 923/3870: unicode-canonical-property-names-ecmascript
# Checking 924/3870: unicode-property-aliases-ecmascript
# Checking 925/3870: buffer-alloc-unsafe
# Checking 926/3870: buffer-fill
# Checking 927/3870: pinkie
# Checking 928/3870: yocto-queue
# Checking 929/3870: is-number
# Checking 930/3870: eastasianwidth
# Checking 931/3870: emoji-regex
# Checking 932/3870: p-try
# Checking 933/3870: spdx-license-ids
# Checking 934/3870: spdx-exceptions
# Checking 935/3870: is-arrayish
# Checking 936/3870: node
# Checking 937/3870: ava
# Checking 938/3870: c8
# Checking 939/3870: execa
# Checking 940/3870: log-update
# Checking 941/3870: cli-cursor
# Checking 942/3870: slice-ansi
# Checking 943/3870: restore-cursor
# Checking 944/3870: is-fullwidth-code-point
# Checking 945/3870: onetime
# Checking 946/3870: mimic-fn
# Checking 947/3870: matcha
# Checking 948/3870: tsd
# Checking 949/3870: xo
# Checking 950/3870: arrify
# Checking 951/3870: eslint-formatter-pretty
# Checking 952/3870: eslint
# Checking 953/3870: eslint-plugin-prettier
# Checking 954/3870: meow
# Checking 955/3870: ansi-escapes
# Checking 956/3870: chalk
# Checking 957/3870: log-symbols
# Checking 958/3870: plur
# Checking 959/3870: string-width
# Checking 960/3870: supports-hyperlinks
# Checking 961/3870: eslint
# Checking 962/3870: is-unicode-supported
# Checking 963/3870: emoji-regex
# Checking 964/3870: yoctodelay
# Checking 965/3870: react
# Checking 966/3870: acorn-walk
# Checking 967/3870: arrgv
# Checking 968/3870: arrify
# Checking 969/3870: chokidar
# Checking 970/3870: chunkd
# Checking 971/3870: ci-info
# Checking 972/3870: ci-parallel-vars
# Checking 973/3870: clean-yaml-object
# Checking 974/3870: cli-cursor
# Checking 975/3870: cli-truncate
# Checking 976/3870: code-excerpt
# Checking 977/3870: common-path-prefix
# Checking 978/3870: concordance
# Checking 979/3870: currently-unhandled
# Checking 980/3870: del
# Checking 981/3870: emittery
# Checking 982/3870: equal-length
# Checking 983/3870: figures
# Checking 984/3870: ignore-by-default
# Checking 985/3870: import-local
# Checking 986/3870: is-error
# Checking 987/3870: is-plain-object
# Checking 988/3870: is-promise
# Checking 989/3870: lodash
# Checking 990/3870: matcher
# Checking 991/3870: md5-hex
# Checking 992/3870: mem
# Checking 993/3870: ora
# Checking 994/3870: p-event
# Checking 995/3870: p-map
# Checking 996/3870: pkg-conf
# Checking 997/3870: find-up
# Checking 998/3870: locate-path
# Checking 999/3870: p-locate
# Checking 1000/3870: path-exists
# Checking 1001/3870: pretty-ms
# Checking 1002/3870: resolve-cwd
# Checking 1003/3870: stack-utils
# Checking 1004/3870: escape-string-regexp
# Checking 1005/3870: supertap
# Checking 1006/3870: temp-dir
# Checking 1007/3870: trim-off-newlines
# Checking 1008/3870: update-notifier
# Checking 1009/3870: yargs
# Checking 1010/3870: v8-coverage
# Checking 1011/3870: v8-to-istanbul
# Checking 1012/3870: get-stream
# Checking 1013/3870: human-signals
# Checking 1014/3870: is-stream
# Checking 1015/3870: npm-run-path
# Checking 1016/3870: path-key
# Checking 1017/3870: onetime
# Checking 1018/3870: mimic-fn
# Checking 1019/3870: strip-final-newline
# Checking 1020/3870: ansi-escapes
# Checking 1021/3870: electron
# Checking 1022/3870: v8-argv
# Checking 1023/3870: typescript
# Checking 1024/3870: eslintrc
# Checking 1025/3870: eslint-plugin
# Checking 1026/3870: parser
# Checking 1027/3870: cosmiconfig
# Checking 1028/3870: define-lazy-prop
# Checking 1029/3870: eslint-config-prettier
# Checking 1030/3870: eslint-config-xo-typescript
# Checking 1031/3870: eslint-config-xo
# Checking 1032/3870: eslint-import-resolver-webpack
# Checking 1033/3870: debug
# Checking 1034/3870: resolve
# Checking 1035/3870: eslint-plugin-ava
# Checking 1036/3870: pkg-dir
# Checking 1037/3870: eslint-plugin-eslint-comments
# Checking 1038/3870: eslint-plugin-import
# Checking 1039/3870: doctrine
# Checking 1040/3870: eslint-plugin-n
# Checking 1041/3870: eslint-plugin-no-use-extend-native
# Checking 1042/3870: eslint-plugin-unicorn
# Checking 1043/3870: ci-info
# Checking 1044/3870: esm-utils
# Checking 1045/3870: find-cache-dir
# Checking 1046/3870: pkg-dir
# Checking 1047/3870: find-up
# Checking 1048/3870: locate-path
# Checking 1049/3870: path-exists
# Checking 1050/3870: p-locate
# Checking 1051/3870: p-limit
# Checking 1052/3870: yocto-queue
# Checking 1053/3870: find-up-simple
# Checking 1054/3870: get-stdin
# Checking 1055/3870: get-tsconfig
# Checking 1056/3870: lodash-es
# Checking 1057/3870: open-editor
# Checking 1058/3870: execa
# Checking 1059/3870: human-signals
# Checking 1060/3870: npm-run-path
# Checking 1061/3870: strip-final-newline
# Checking 1062/3870: prettier
# Checking 1063/3870: to-absolute-glob
# Checking 1064/3870: anymatch
# Checking 1065/3870: fsevents
# Checking 1066/3870: is-binary-path
# Checking 1067/3870: normalize-path
# Checking 1068/3870: readdirp
# Checking 1069/3870: restore-cursor
# Checking 1070/3870: slice-ansi
# Checking 1071/3870: convert-to-spaces
# Checking 1072/3870: date-time
# Checking 1073/3870: fast-diff
# Checking 1074/3870: js-string-escape
# Checking 1075/3870: well-known-symbols
# Checking 1076/3870: array-find-index
# Checking 1077/3870: is-path-cwd
# Checking 1078/3870: blueimp-md5
# Checking 1079/3870: map-age-cleaner
# Checking 1080/3870: mimic-fn
# Checking 1081/3870: bl
# Checking 1082/3870: cli-spinners
# Checking 1083/3870: is-interactive
# Checking 1084/3870: wcwidth
# Checking 1085/3870: p-timeout
# Checking 1086/3870: load-json-file
# Checking 1087/3870: type-fest
# Checking 1088/3870: parse-ms
# Checking 1089/3870: serialize-error
# Checking 1090/3870: type-fest
# Checking 1091/3870: boxen
# Checking 1092/3870: configstore
# Checking 1093/3870: has-yarn
# Checking 1094/3870: import-lazy
# Checking 1095/3870: is-ci
# Checking 1096/3870: is-installed-globally
# Checking 1097/3870: is-npm
# Checking 1098/3870: is-yarn-global
# Checking 1099/3870: latest-version
# Checking 1100/3870: pupa
# Checking 1101/3870: semver-diff
# Checking 1102/3870: xdg-basedir
# Checking 1103/3870: cliui
# Checking 1104/3870: istanbul-lib-coverage
# Checking 1105/3870: type-fest
# Checking 1106/3870: drip
# Checking 1107/3870: espree
# Checking 1108/3870: globals
# Checking 1109/3870: scope-manager
# Checking 1110/3870: type-utils
# Checking 1111/3870: utils
# Checking 1112/3870: visitor-keys
# Checking 1113/3870: ts-api-utils
# Checking 1114/3870: types
# Checking 1115/3870: typescript-estree
# Checking 1116/3870: minimatch
# Checking 1117/3870: confusing-browser-globals
# Checking 1118/3870: enhanced-resolve
# Checking 1119/3870: find-root
# Checking 1120/3870: interpret
# Checking 1121/3870: enhance-visitors
# Checking 1122/3870: eslint-utils
# Checking 1123/3870: eslint-visitor-keys
# Checking 1124/3870: espurify
# Checking 1125/3870: import-modules
# Checking 1126/3870: micro-spelling-correcter
# Checking 1127/3870: scc
# Checking 1128/3870: array-includes
# Checking 1129/3870: array.prototype.findlastindex
# Checking 1130/3870: array.prototype.flat
# Checking 1131/3870: array.prototype.flatmap
# Checking 1132/3870: eslint-import-resolver-node
# Checking 1133/3870: eslint-module-utils
# Checking 1134/3870: object.fromentries
# Checking 1135/3870: object.groupby
# Checking 1136/3870: object.values
# Checking 1137/3870: string.prototype.trimend
# Checking 1138/3870: tsconfig-paths
# Checking 1139/3870: builtins
# Checking 1140/3870: eslint-plugin-es-x
# Checking 1141/3870: is-builtin-module
# Checking 1142/3870: is-get-set-prop
# Checking 1143/3870: is-js-type
# Checking 1144/3870: is-obj-prop
# Checking 1145/3870: is-proto-prop
# Checking 1146/3870: prettier-linter-helpers
# Checking 1147/3870: synckit
# Checking 1148/3870: clean-regexp
# Checking 1149/3870: pluralize
# Checking 1150/3870: regexp-tree
# Checking 1151/3870: regjsparser
# Checking 1152/3870: jsesc
# Checking 1153/3870: import-meta-resolve
# Checking 1154/3870: url-or-path
# Checking 1155/3870: resolve-pkg-maps
# Checking 1156/3870: env-editor
# Checking 1157/3870: line-column-path
# Checking 1158/3870: type-fest
# Checking 1159/3870: open
# Checking 1160/3870: define-lazy-prop
# Checking 1161/3870: is-absolute
# Checking 1162/3870: is-negated-glob
# Checking 1163/3870: binary-extensions
# Checking 1164/3870: astral-regex
# Checking 1165/3870: time-zone
# Checking 1166/3870: p-defer
# Checking 1167/3870: defaults
# Checking 1168/3870: p-finally
# Checking 1169/3870: parse-json
# Checking 1170/3870: pify
# Checking 1171/3870: strip-bom
# Checking 1172/3870: ansi-align
# Checking 1173/3870: cli-boxes
# Checking 1174/3870: widest-line
# Checking 1175/3870: dot-prop
# Checking 1176/3870: unique-string
# Checking 1177/3870: global-dirs
# Checking 1178/3870: package-json
# Checking 1179/3870: escape-goat
# Checking 1180/3870: tea-concat
# Checking 1181/3870: semver
# Checking 1182/3870: get-east-asian-width
# Checking 1183/3870: memory-fs
# Checking 1184/3870: tapable
# Checking 1185/3870: es-abstract
# Checking 1186/3870: es-shim-unscopables
# Checking 1187/3870: json5
# Checking 1188/3870: json5
# Checking 1189/3870: eslint-compat-utils
# Checking 1190/3870: builtin-modules
# Checking 1191/3870: get-set-props
# Checking 1192/3870: lowercase-keys
# Checking 1193/3870: js-types
# Checking 1194/3870: obj-props
# Checking 1195/3870: proto-props
# Checking 1196/3870: core
# Checking 1197/3870: is-docker
# Checking 1198/3870: is-wsl
# Checking 1199/3870: is-relative
# Checking 1200/3870: string_decoder
# Checking 1201/3870: clone
# Checking 1202/3870: json-parse-better-errors
# Checking 1203/3870: is-obj
# Checking 1204/3870: crypto-random-string
# Checking 1205/3870: ini
# Checking 1206/3870: got
# Checking 1207/3870: get-stream
# Checking 1208/3870: registry-auth-token
# Checking 1209/3870: registry-url
# Checking 1210/3870: array-buffer-byte-length
# Checking 1211/3870: arraybuffer.prototype.slice
# Checking 1212/3870: data-view-buffer
# Checking 1213/3870: data-view-byte-length
# Checking 1214/3870: data-view-byte-offset
# Checking 1215/3870: es-set-tostringtag
# Checking 1216/3870: es-to-primitive
# Checking 1217/3870: function.prototype.name
# Checking 1218/3870: get-symbol-description
# Checking 1219/3870: globalthis
# Checking 1220/3870: has-proto
# Checking 1221/3870: internal-slot
# Checking 1222/3870: is-array-buffer
# Checking 1223/3870: is-data-view
# Checking 1224/3870: is-negative-zero
# Checking 1225/3870: is-set
# Checking 1226/3870: is-shared-array-buffer
# Checking 1227/3870: is-weakref
# Checking 1228/3870: object.assign
# Checking 1229/3870: own-keys
# Checking 1230/3870: regexp.prototype.flags
# Checking 1231/3870: safe-array-concat
# Checking 1232/3870: safe-push-apply
# Checking 1233/3870: set-proto
# Checking 1234/3870: stop-iteration-iterator
# Checking 1235/3870: string.prototype.trim
# Checking 1236/3870: string.prototype.trimstart
# Checking 1237/3870: typed-array-byte-length
# Checking 1238/3870: typed-array-byte-offset
# Checking 1239/3870: typed-array-length
# Checking 1240/3870: unbox-primitive
# Checking 1241/3870: is-unc-path
# Checking 1242/3870: is
# Checking 1243/3870: http-timer
# Checking 1244/3870: cacheable-request
# Checking 1245/3870: get-stream
# Checking 1246/3870: lowercase-keys
# Checking 1247/3870: decompress-response
# Checking 1248/3870: duplexer3
# Checking 1249/3870: mimic-response
# Checking 1250/3870: p-cancelable
# Checking 1251/3870: to-readable-stream
# Checking 1252/3870: url-parse-lax
# Checking 1253/3870: rc
# Checking 1254/3870: ini
# Checking 1255/3870: is-date-object
# Checking 1256/3870: is-symbol
# Checking 1257/3870: functions-have-names
# Checking 1258/3870: set-function-name
# Checking 1259/3870: reflect.getprototypeof
# Checking 1260/3870: has-bigints
# Checking 1261/3870: which-boxed-primitive
# Checking 1262/3870: unc-path-regex
# Checking 1263/3870: defer-to-connect
# Checking 1264/3870: clone-response
# Checking 1265/3870: http-cache-semantics
# Checking 1266/3870: keyv
# Checking 1267/3870: normalize-url
# Checking 1268/3870: responselike
# Checking 1269/3870: pump
# Checking 1270/3870: prepend-http
# Checking 1271/3870: deep-extend
# Checking 1272/3870: strip-json-comments
# Checking 1273/3870: which-builtin-type
# Checking 1274/3870: is-bigint
# Checking 1275/3870: is-boolean-object
# Checking 1276/3870: is-number-object
# Checking 1277/3870: json-buffer
# Checking 1278/3870: is-async-function
# Checking 1279/3870: is-finalizationregistry
# Checking 1280/3870: which-collection
# Checking 1281/3870: async-function
# Checking 1282/3870: is-map
# Checking 1283/3870: is-weakmap
# Checking 1284/3870: is-weakset
# Checking 1285/3870: jest
# Checking 1286/3870: node-addon-api
# Checking 1287/3870: node-gyp-build
# Checking 1288/3870: prebuildify
# Checking 1289/3870: npm-run-path
# Checking 1290/3870: core
# Checking 1291/3870: types
# Checking 1292/3870: jest-cli
# Checking 1293/3870: mkdirp-classic
# Checking 1294/3870: node-abi
# Checking 1295/3870: pump
# Checking 1296/3870: tar-fs
# Checking 1297/3870: console
# Checking 1298/3870: reporters
# Checking 1299/3870: test-result
# Checking 1300/3870: transform
# Checking 1301/3870: node
# Checking 1302/3870: ci-info
# Checking 1303/3870: exit
# Checking 1304/3870: jest-changed-files
# Checking 1305/3870: jest-config
# Checking 1306/3870: jest-haste-map
# Checking 1307/3870: jest-message-util
# Checking 1308/3870: jest-regex-util
# Checking 1309/3870: jest-resolve-dependencies
# Checking 1310/3870: jest-resolve
# Checking 1311/3870: jest-runner
# Checking 1312/3870: jest-runtime
# Checking 1313/3870: jest-snapshot
# Checking 1314/3870: jest-util
# Checking 1315/3870: jest-validate
# Checking 1316/3870: jest-watcher
# Checking 1317/3870: istanbul-reports
# Checking 1318/3870: yargs
# Checking 1319/3870: create-jest
# Checking 1320/3870: end-of-stream
# Checking 1321/3870: chownr
# Checking 1322/3870: tar-stream
# Checking 1323/3870: trace-mapping
# Checking 1324/3870: collect-v8-coverage
# Checking 1325/3870: istanbul-lib-instrument
# Checking 1326/3870: istanbul-reports
# Checking 1327/3870: jest-worker
# Checking 1328/3870: string-length
# Checking 1329/3870: core
# Checking 1330/3870: babel-plugin-istanbul
# Checking 1331/3870: istanbul-lib-instrument
# Checking 1332/3870: pirates
# Checking 1333/3870: write-file-atomic
# Checking 1334/3870: undici-types
# Checking 1335/3870: test-sequencer
# Checking 1336/3870: babel-jest
# Checking 1337/3870: deepmerge
# Checking 1338/3870: jest-circus
# Checking 1339/3870: jest-environment-node
# Checking 1340/3870: graceful-fs
# Checking 1341/3870: fb-watchman
# Checking 1342/3870: walker
# Checking 1343/3870: code-frame
# Checking 1344/3870: stack-utils
# Checking 1345/3870: jest-pnp-resolver
# Checking 1346/3870: resolve.exports
# Checking 1347/3870: environment
# Checking 1348/3870: emittery
# Checking 1349/3870: jest-docblock
# Checking 1350/3870: jest-leak-detector
# Checking 1351/3870: source-map-support
# Checking 1352/3870: fake-timers
# Checking 1353/3870: globals
# Checking 1354/3870: source-map
# Checking 1355/3870: cjs-module-lexer
# Checking 1356/3870: jest-mock
# Checking 1357/3870: generator
# Checking 1358/3870: plugin-syntax-jsx
# Checking 1359/3870: plugin-syntax-typescript
# Checking 1360/3870: types
# Checking 1361/3870: expect-utils
# Checking 1362/3870: babel-preset-current-node-syntax
# Checking 1363/3870: expect
# Checking 1364/3870: jest-matcher-utils
# Checking 1365/3870: leven
# Checking 1366/3870: istanbul-lib-report
# Checking 1367/3870: yargs-parser
# Checking 1368/3870: prompts
# Checking 1369/3870: sourcemap-codec
# Checking 1370/3870: parser
# Checking 1371/3870: debug
# Checking 1372/3870: char-regex
# Checking 1373/3870: helper-compilation-targets
# Checking 1374/3870: helper-module-transforms
# Checking 1375/3870: helpers
# Checking 1376/3870: template
# Checking 1377/3870: traverse
# Checking 1378/3870: helper-plugin-utils
# Checking 1379/3870: babel__core
# Checking 1380/3870: babel-preset-jest
# Checking 1381/3870: co
# Checking 1382/3870: dedent
# Checking 1383/3870: is-generator-fn
# Checking 1384/3870: jest-each
# Checking 1385/3870: pure-rand
# Checking 1386/3870: bser
# Checking 1387/3870: makeerror
# Checking 1388/3870: helper-validator-identifier
# Checking 1389/3870: detect-newline
# Checking 1390/3870: fake-timers
# Checking 1391/3870: gen-mapping
# Checking 1392/3870: helper-string-parser
# Checking 1393/3870: plugin-syntax-async-generators
# Checking 1394/3870: plugin-syntax-bigint
# Checking 1395/3870: plugin-syntax-class-properties
# Checking 1396/3870: plugin-syntax-class-static-block
# Checking 1397/3870: plugin-syntax-import-attributes
# Checking 1398/3870: plugin-syntax-import-meta
# Checking 1399/3870: plugin-syntax-json-strings
# Checking 1400/3870: plugin-syntax-logical-assignment-operators
# Checking 1401/3870: plugin-syntax-nullish-coalescing-operator
# Checking 1402/3870: plugin-syntax-numeric-separator
# Checking 1403/3870: plugin-syntax-object-rest-spread
# Checking 1404/3870: plugin-syntax-optional-catch-binding
# Checking 1405/3870: plugin-syntax-optional-chaining
# Checking 1406/3870: plugin-syntax-private-property-in-object
# Checking 1407/3870: plugin-syntax-top-level-await
# Checking 1408/3870: kleur
# Checking 1409/3870: sisteransi
# Checking 1410/3870: brace-expansion
# Checking 1411/3870: compat-data
# Checking 1412/3870: helper-validator-option
# Checking 1413/3870: browserslist
# Checking 1414/3870: helper-module-imports
# Checking 1415/3870: globals
# Checking 1416/3870: babel__generator
# Checking 1417/3870: babel__template
# Checking 1418/3870: babel__traverse
# Checking 1419/3870: babel-plugin-jest-hoist
# Checking 1420/3870: node-int64
# Checking 1421/3870: tmpl
# Checking 1422/3870: set-array
# Checking 1423/3870: caniuse-lite
# Checking 1424/3870: electron-to-chromium
# Checking 1425/3870: node-releases
# Checking 1426/3870: update-browserslist-db
# Checking 1427/3870: test
# Checking 1428/3870: postcss-import
# Checking 1429/3870: postcss
# Checking 1430/3870: prettier-plugin-embed
# Checking 1431/3870: prettier-plugin-organize-imports
# Checking 1432/3870: tsup
# Checking 1433/3870: turbo
# ...
# Checking 3470/3870: cst
# Checking 3471/3870: jscs-jsdoc
# Checking 3472/3870: jscs-preset-wikimedia
# Checking 3473/3870: jsonlint
# Checking 3474/3870: natural-compare
# Checking 3475/3870: pathval
# Checking 3476/3870: prompt
# Checking 3477/3870: reserved-words
# Checking 3478/3870: strip-bom
# Checking 3479/3870: strip-json-comments
# Checking 3480/3870: to-double-quotes
# Checking 3481/3870: to-single-quotes
# Checking 3482/3870: vow-fs
# Checking 3483/3870: vow
# Checking 3484/3870: xmlbuilder
# Checking 3485/3870: babel-core
# Checking 3486/3870: babel-preset-es2015
# Checking 3487/3870: babel-preset-stage-0
# Checking 3488/3870: cross-spawn
# Checking 3489/3870: lodash.assign
# Checking 3490/3870: exists-stat
# Checking 3491/3870: findup-sync
# Checking 3492/3870: js-reporters
# Checking 3493/3870: walk-sync
# Checking 3494/3870: isstream
# Checking 3495/3870: performance-now
# Checking 3496/3870: uglify-to-browserify
# Checking 3497/3870: yargs
# Checking 3498/3870: acorn
# Checking 3499/3870: interpret
# Checking 3500/3870: loader-utils
# Checking 3501/3870: memory-fs
# Checking 3502/3870: node-libs-browser
# Checking 3503/3870: optimist
# Checking 3504/3870: minimist
# Checking 3505/3870: wordwrap
# Checking 3506/3870: watchpack
# Checking 3507/3870: async
# Checking 3508/3870: webpack-core
# Checking 3509/3870: source-map
# Checking 3510/3870: css-what
# Checking 3511/3870: domutils
# Checking 3512/3870: nth-check
# Checking 3513/3870: domelementtype
# Checking 3514/3870: domhandler
# Checking 3515/3870: readable-stream
# Checking 3516/3870: aws-sign2
# Checking 3517/3870: bl
# Checking 3518/3870: caseless
# Checking 3519/3870: forever-agent
# Checking 3520/3870: form-data
# Checking 3521/3870: mime
# Checking 3522/3870: hawk
# Checking 3523/3870: http-signature
# Checking 3524/3870: mime-types
# Checking 3525/3870: node-uuid
# Checking 3526/3870: oauth-sign
# Checking 3527/3870: qs
# Checking 3528/3870: tough-cookie
# Checking 3529/3870: tunnel-agent
# Checking 3530/3870: tape
# Checking 3531/3870: aws4
# Checking 3532/3870: extend
# Checking 3533/3870: har-validator
# Checking 3534/3870: estraverse
# Checking 3535/3870: optionator
# Checking 3536/3870: source-map
# Checking 3537/3870: neo-async
# Checking 3538/3870: has-flag
# Checking 3539/3870: graceful-readlink
# Checking 3540/3870: babel-runtime
# Checking 3541/3870: babylon
# Checking 3542/3870: source-map-support
# Checking 3543/3870: inherit
# Checking 3544/3870: comment-parser
# Checking 3545/3870: jsdoctypeparser
# Checking 3546/3870: JSV
# Checking 3547/3870: nomnom
# Checking 3548/3870: chalk
# Checking 3549/3870: ansi-styles
# Checking 3550/3870: strip-ansi
# Checking 3551/3870: pkginfo
# Checking 3552/3870: read
# Checking 3553/3870: revalidator
# Checking 3554/3870: utile
# Checking 3555/3870: winston
# Checking 3556/3870: colors
# Checking 3557/3870: pkginfo
# Checking 3558/3870: is-utf8
# Checking 3559/3870: vow-queue
# Checking 3560/3870: babel-code-frame
# Checking 3561/3870: babel-generator
# Checking 3562/3870: babel-helpers
# Checking 3563/3870: babel-messages
# Checking 3564/3870: babel-register
# Checking 3565/3870: babel-template
# Checking 3566/3870: babel-traverse
# Checking 3567/3870: babel-types
# Checking 3568/3870: convert-source-map
# Checking 3569/3870: json5
# Checking 3570/3870: private
# Checking 3571/3870: slash
# Checking 3572/3870: babel-plugin-check-es2015-constants
# Checking 3573/3870: babel-plugin-transform-es2015-arrow-functions
# Checking 3574/3870: babel-plugin-transform-es2015-block-scoped-functions
# Checking 3575/3870: babel-plugin-transform-es2015-block-scoping
# Checking 3576/3870: babel-plugin-transform-es2015-classes
# Checking 3577/3870: babel-plugin-transform-es2015-computed-properties
# Checking 3578/3870: babel-plugin-transform-es2015-destructuring
# Checking 3579/3870: babel-plugin-transform-es2015-duplicate-keys
# Checking 3580/3870: babel-plugin-transform-es2015-for-of
# Checking 3581/3870: babel-plugin-transform-es2015-function-name
# Checking 3582/3870: babel-plugin-transform-es2015-literals
# Checking 3583/3870: babel-plugin-transform-es2015-modules-amd
# Checking 3584/3870: babel-plugin-transform-es2015-modules-commonjs
# Checking 3585/3870: babel-plugin-transform-es2015-modules-systemjs
# Checking 3586/3870: babel-plugin-transform-es2015-modules-umd
# Checking 3587/3870: babel-plugin-transform-es2015-object-super
# Checking 3588/3870: babel-plugin-transform-es2015-parameters
# Checking 3589/3870: babel-plugin-transform-es2015-shorthand-properties
# Checking 3590/3870: babel-plugin-transform-es2015-spread
# Checking 3591/3870: babel-plugin-transform-es2015-sticky-regex
# Checking 3592/3870: babel-plugin-transform-es2015-template-literals
# Checking 3593/3870: babel-plugin-transform-es2015-typeof-symbol
# Checking 3594/3870: babel-plugin-transform-es2015-unicode-regex
# Checking 3595/3870: babel-plugin-transform-regenerator
# Checking 3596/3870: babel-plugin-transform-do-expressions
# Checking 3597/3870: babel-plugin-transform-function-bind
# Checking 3598/3870: babel-preset-stage-1
# Checking 3599/3870: lru-cache
# Checking 3600/3870: shebang-command
# Checking 3601/3870: get-caller-file
# Checking 3602/3870: os-locale
# Checking 3603/3870: read-pkg-up
# Checking 3604/3870: require-main-filename
# Checking 3605/3870: string-width
# Checking 3606/3870: which-module
# Checking 3607/3870: y18n
# Checking 3608/3870: yargs-parser
# Checking 3609/3870: anymatch
# Checking 3610/3870: async-each
# Checking 3611/3870: fsevents
# Checking 3612/3870: node-pre-gyp
# Checking 3613/3870: detect-libc
# Checking 3614/3870: needle
# Checking 3615/3870: nopt
# Checking 3616/3870: npm-packlist
# Checking 3617/3870: rc
# Checking 3618/3870: rimraf
# Checking 3619/3870: semver
# Checking 3620/3870: tar
# Checking 3621/3870: iconv-lite
# Checking 3622/3870: sax
# Checking 3623/3870: osenv
# Checking 3624/3870: ignore-walk
# Checking 3625/3870: npm-bundled
# Checking 3626/3870: are-we-there-yet
# Checking 3627/3870: gauge
# Checking 3628/3870: deep-extend
# Checking 3629/3870: ini
# Checking 3630/3870: glob
# Checking 3631/3870: chownr
# Checking 3632/3870: fs-minipass
# Checking 3633/3870: minipass
# Checking 3634/3870: minizlib
# Checking 3635/3870: safe-buffer
# Checking 3636/3870: yallist
# Checking 3637/3870: os-homedir
# Checking 3638/3870: aproba
# Checking 3639/3870: signal-exit
# Checking 3640/3870: wide-align
# Checking 3641/3870: process-nextick-args
# Checking 3642/3870: code-point-at
# Checking 3643/3870: is-fullwidth-code-point
# Checking 3644/3870: number-is-nan
# Checking 3645/3870: glob-parent
# Checking 3646/3870: is-binary-path
# Checking 3647/3870: is-glob
# Checking 3648/3870: readdirp
# Checking 3649/3870: detect-file
# Checking 3650/3870: micromatch
# Checking 3651/3870: resolve-dir
# Checking 3652/3870: path-parse
# Checking 3653/3870: ensure-posix-path
# Checking 3654/3870: matcher-collection
# Checking 3655/3870: ajv
# Checking 3656/3870: har-schema
# Checking 3657/3870: jsprim
# Checking 3658/3870: sshpk
# Checking 3659/3870: asn1
# Checking 3660/3870: psl
# Checking 3661/3870: cliui
# Checking 3662/3870: wordwrap
# Checking 3663/3870: window-size
# Checking 3664/3870: big.js
# Checking 3665/3870: emojis-list
# Checking 3666/3870: errno
# Checking 3667/3870: assert
# Checking 3668/3870: browserify-zlib
# Checking 3669/3870: buffer
# Checking 3670/3870: console-browserify
# Checking 3671/3870: constants-browserify
# Checking 3672/3870: crypto-browserify
# Checking 3673/3870: domain-browser
# Checking 3674/3870: events
# Checking 3675/3870: https-browserify
# Checking 3676/3870: os-browserify
# Checking 3677/3870: path-browserify
# Checking 3678/3870: querystring-es3
# Checking 3679/3870: stream-browserify
# Checking 3680/3870: stream-http
# Checking 3681/3870: timers-browserify
# Checking 3682/3870: tty-browserify
# Checking 3683/3870: url
# Checking 3684/3870: punycode
# Checking 3685/3870: util
# Checking 3686/3870: inherits
# Checking 3687/3870: vm-browserify
# Checking 3688/3870: chokidar
# Checking 3689/3870: source-list-map
# Checking 3690/3870: combined-stream
# Checking 3691/3870: boom
# Checking 3692/3870: cryptiles
# Checking 3693/3870: hoek
# Checking 3694/3870: sntp
# Checking 3695/3870: asn1
# Checking 3696/3870: assert-plus
# Checking 3697/3870: ctype
# Checking 3698/3870: deep-equal
# Checking 3699/3870: defined
# Checking 3700/3870: jsonify
# Checking 3701/3870: resumer
# Checking 3702/3870: split
# Checking 3703/3870: stream-combiner
# Checking 3704/3870: is-my-json-valid
# Checking 3705/3870: mime-db
# Checking 3706/3870: levn
# Checking 3707/3870: prelude-ls
# Checking 3708/3870: type-check
# Checking 3709/3870: amdefine
# Checking 3710/3870: core-js
# Checking 3711/3870: regenerator-runtime
# Checking 3712/3870: underscore
# Checking 3713/3870: mute-stream
# Checking 3714/3870: i
# Checking 3715/3870: ncp
# Checking 3716/3870: cycle
# Checking 3717/3870: eyes
# Checking 3718/3870: stack-trace
# Checking 3719/3870: js-tokens
# Checking 3720/3870: detect-indent
# Checking 3721/3870: jsesc
# Checking 3722/3870: trim-right
# Checking 3723/3870: home-or-tmp
# Checking 3724/3870: globals
# Checking 3725/3870: invariant
# Checking 3726/3870: to-fast-properties
# Checking 3727/3870: babel-helper-define-map
# Checking 3728/3870: babel-helper-function-name
# Checking 3729/3870: babel-helper-optimise-call-expression
# Checking 3730/3870: babel-helper-replace-supers
# Checking 3731/3870: babel-plugin-transform-strict-mode
# Checking 3732/3870: babel-helper-hoist-variables
# Checking 3733/3870: babel-helper-call-delegate
# Checking 3734/3870: babel-helper-get-function-arity
# Checking 3735/3870: babel-helper-regex
# Checking 3736/3870: regexpu-core
# Checking 3737/3870: regenerator-transform
# Checking 3738/3870: babel-plugin-syntax-do-expressions
# Checking 3739/3870: babel-plugin-syntax-function-bind
# Checking 3740/3870: babel-plugin-transform-class-constructor-call
# Checking 3741/3870: babel-plugin-transform-export-extensions
# Checking 3742/3870: babel-preset-stage-2
# Checking 3743/3870: shebang-regex
# Checking 3744/3870: wrap-ansi
# Checking 3745/3870: lcid
# Checking 3746/3870: find-up
# Checking 3747/3870: read-pkg
# Checking 3748/3870: normalize-path
# Checking 3749/3870: nan
# Checking 3750/3870: binary-extensions
# Checking 3751/3870: is-extglob
# Checking 3752/3870: set-immediate-shim
# Checking 3753/3870: fs-exists-sync
# Checking 3754/3870: arr-diff
# Checking 3755/3870: array-unique
# Checking 3756/3870: braces
# Checking 3757/3870: expand-brackets
# Checking 3758/3870: extglob
# Checking 3759/3870: filename-regex
# Checking 3760/3870: kind-of
# Checking 3761/3870: object.omit
# Checking 3762/3870: parse-glob
# Checking 3763/3870: regex-cache
# Checking 3764/3870: expand-tilde
# Checking 3765/3870: global-modules
# Checking 3766/3870: fast-json-stable-stringify
# Checking 3767/3870: uri-js
# Checking 3768/3870: extsprintf
# Checking 3769/3870: json-schema
# Checking 3770/3870: verror
# Checking 3771/3870: bcrypt-pbkdf
# Checking 3772/3870: dashdash
# Checking 3773/3870: ecc-jsbn
# Checking 3774/3870: getpass
# Checking 3775/3870: jsbn
# Checking 3776/3870: tweetnacl
# Checking 3777/3870: center-align
# Checking 3778/3870: right-align
# Checking 3779/3870: pako
# Checking 3780/3870: base64-js
# Checking 3781/3870: ieee754
# Checking 3782/3870: date-now
# Checking 3783/3870: browserify-aes
# Checking 3784/3870: pbkdf2-compat
# Checking 3785/3870: ripemd160
# Checking 3786/3870: sha.js
# Checking 3787/3870: builtin-status-codes
# Checking 3788/3870: to-arraybuffer
# Checking 3789/3870: xtend
# Checking 3790/3870: querystring
# Checking 3791/3870: delayed-stream
# Checking 3792/3870: duplexer
# Checking 3793/3870: generate-function
# Checking 3794/3870: generate-object-property
# Checking 3795/3870: is-my-ip-valid
# Checking 3796/3870: jsonpointer
# Checking 3797/3870: has-color
# Checking 3798/3870: repeating
# Checking 3799/3870: loose-envify
# Checking 3800/3870: regenerate
# Checking 3801/3870: regjsgen
# Checking 3802/3870: regjsparser
# Checking 3803/3870: babel-plugin-syntax-class-constructor-call
# Checking 3804/3870: babel-plugin-syntax-export-extensions
# Checking 3805/3870: babel-plugin-syntax-dynamic-import
# Checking 3806/3870: babel-plugin-transform-class-properties
# Checking 3807/3870: babel-plugin-transform-decorators
# Checking 3808/3870: babel-preset-stage-3
# Checking 3809/3870: invert-kv
# Checking 3810/3870: path-exists
# Checking 3811/3870: load-json-file
# Checking 3812/3870: normalize-package-data
# Checking 3813/3870: path-type
# Checking 3814/3870: remove-trailing-separator
# Checking 3815/3870: arr-flatten
# Checking 3816/3870: expand-range
# Checking 3817/3870: preserve
# Checking 3818/3870: repeat-element
# Checking 3819/3870: is-posix-bracket
# Checking 3820/3870: is-buffer
# Checking 3821/3870: for-own
# Checking 3822/3870: is-extendable
# Checking 3823/3870: glob-base
# Checking 3824/3870: is-dotfile
# Checking 3825/3870: is-equal-shallow
# Checking 3826/3870: global-prefix
# Checking 3827/3870: is-windows
# Checking 3828/3870: align-text
# Checking 3829/3870: lazy-cache
# Checking 3830/3870: is-property
# Checking 3831/3870: is-finite
# Checking 3832/3870: babel-plugin-syntax-class-properties
# Checking 3833/3870: babel-helper-explode-class
# Checking 3834/3870: babel-plugin-syntax-decorators
# Checking 3835/3870: babel-plugin-syntax-trailing-function-commas
# Checking 3836/3870: babel-plugin-transform-async-generator-functions
# Checking 3837/3870: babel-plugin-transform-async-to-generator
# Checking 3838/3870: babel-plugin-transform-exponentiation-operator
# Checking 3839/3870: babel-plugin-transform-object-rest-spread
# Checking 3840/3870: parse-json
# Checking 3841/3870: hosted-git-info
# Checking 3842/3870: is-builtin-module
# Checking 3843/3870: validate-npm-package-license
# Checking 3844/3870: fill-range
# Checking 3845/3870: for-in
# Checking 3846/3870: is-primitive
# Checking 3847/3870: homedir-polyfill
# Checking 3848/3870: longest
# Checking 3849/3870: repeat-string
# Checking 3850/3870: babel-helper-bindify-decorators
# Checking 3851/3870: babel-helper-remap-async-to-generator
# Checking 3852/3870: babel-plugin-syntax-async-generators
# Checking 3853/3870: babel-plugin-syntax-async-functions
# Checking 3854/3870: babel-helper-builder-binary-assignment-operator-visitor
# Checking 3855/3870: babel-plugin-syntax-exponentiation-operator
# Checking 3856/3870: babel-plugin-syntax-object-rest-spread
# Checking 3857/3870: error-ex
# Checking 3858/3870: builtin-modules
# Checking 3859/3870: spdx-correct
# Checking 3860/3870: spdx-expression-parse
# Checking 3861/3870: is-number
# Checking 3862/3870: isobject
# Checking 3863/3870: randomatic
# Checking 3864/3870: is-number
# Checking 3865/3870: kind-of
# Checking 3866/3870: parse-passwd
# Checking 3867/3870: babel-helper-explode-assignable-expression
# Checking 3868/3870: spdx-license-ids
# Checking 3869/3870: spdx-exceptions
# Checking 3870/3870: math-random
#
# Results:
#                                          Library Current Version  \
# 0                                           core          7.28.3
# 1                                     preset-env          7.28.3
# 2                             mongodb-downloader           0.4.2
# 3                                  eslint-plugin          8.43.0
# 4                                         parser          8.43.0
# ...                                          ...             ...
# 3865                                parse-passwd           1.0.0
# 3866  babel-helper-explode-assignable-expression          6.24.1
# 3867                            spdx-license-ids           3.0.0
# 3868                             spdx-exceptions           2.1.0
# 3869                                 math-random           1.0.4
#
#      Latest Version                                       Status
# 0           1.0.113  Current version is newer than npm (1.0.113)
# 1              None                                    Not Found
# 2              None                                    Not Found
# 3             1.0.1    Current version is newer than npm (1.0.1)
# 4             0.1.4    Current version is newer than npm (0.1.4)
# ...             ...                                          ...
# 3865          1.0.0                                   Up-to-date
# 3866         6.24.1                                   Up-to-date
# 3867         3.0.22                    Update available (3.0.22)
# 3868          2.5.0                     Update available (2.5.0)
# 3869          2.0.1                     Update available (2.0.1)
#
# [3870 rows x 4 columns]
#
# Saved results to npm_version_check_results.csv

# %% [markdown]
# ## Get the most oudated libraries

# %%
import pandas as pd
from packaging import version
import re

# Load the CSV file
df = pd.read_csv('npm_version_check_results.csv')

def clean_version_for_comparison(ver_string):
    """Clean version string to make it comparable"""
    if not ver_string or pd.isna(ver_string):
        return "0.0.0"

    ver_string = str(ver_string).strip()

    # Remove problematic suffixes
    ver_string = re.sub(r'-security.*', '', ver_string)
    ver_string = re.sub(r'-alpha.*', '', ver_string)
    ver_string = re.sub(r'-beta.*', '', ver_string)
    ver_string = re.sub(r'-rc.*', '', ver_string)
    ver_string = re.sub(r'-SNAPSHOT.*', '', ver_string)

    # Keep only digits and dots
    ver_string = re.sub(r'[^\d\.]', '', ver_string)

    # Ensure x.y.z format
    parts = ver_string.split('.')
    while len(parts) < 3:
        parts.append('0')

    return '.'.join(parts[:3])

def calculate_version_gap(current_ver, latest_ver):
    """Calculate how far behind the current version is"""
    try:
        current_clean = clean_version_for_comparison(current_ver)
        latest_clean = clean_version_for_comparison(latest_ver)

        current_parsed = version.parse(current_clean)
        latest_parsed = version.parse(latest_clean)

        # Calculate major.minor difference as a rough metric
        current_parts = [int(x) for x in current_clean.split('.')]
        latest_parts = [int(x) for x in latest_clean.split('.')]

        major_diff = latest_parts[0] - current_parts[0]
        minor_diff = latest_parts[1] - current_parts[1]
        patch_diff = latest_parts[2] - current_parts[2]

        # Weight major changes more heavily
        gap_score = major_diff * 100 + minor_diff * 10 + patch_diff
        return gap_score
    except:
        return 0

# Filter for libraries that have updates available
outdated_df = df[df['Status'].str.contains('Update available', na=False)].copy()

# Calculate version gap for each outdated library
outdated_df['Version_Gap'] = outdated_df.apply(
    lambda row: calculate_version_gap(row['Current Version'], row['Latest Version']),
    axis=1
)

# Sort by version gap (biggest gaps first) and take top 10
top_outdated = outdated_df.nlargest(10, 'Version_Gap')

print(f"{'Library Name':<30} {'Current':<12} {'Latest':<12}")

for _, row in top_outdated.iterrows():
    print(f"{row['Library']:<30} {row['Current Version']:<12} {row['Latest Version']:<12}")

print(f"\nTotal outdated libraries: {len(outdated_df)} out of {len(df)}")
# Out:
# Library Name                   Current      Latest
# devtools-protocol              0.0.1120988  0.0.1512837
# devtools-protocol              0.0.1147663  0.0.1512837
# devtools-protocol              0.0.1302984  0.0.1512837
# api-extractor                  7.52.8       99.99.99
# electron                       0.4.1        38.0.0
# jest                           2.1.1        30.1.3
# expect                         2.1.9        30.1.2
# pretty-format                  2.1.9        30.0.5
# node                           0.16.6       20.19.5
# react                          2.0.0        19.1.1
#
# Total outdated libraries: 1799 out of 3870

# %% [markdown]
# ## The top most updated libraries

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('npm_version_check_results.csv')

# Show up-to-date libraries (limit to top 10)
updated_df = df[df['Status'].isin(['Up-to-date', 'Current version is newer than npm'])]

print(f"{'Library Name':<30} {'Current':<12} {'Latest':<12}")

# Show only first 10 up-to-date libraries
for _, row in updated_df.head(10).iterrows():
    print(f"{row['Library']:<30} {row['Current Version']:<12} {row['Latest Version']:<12}")

print(f"\nTotal up-to-date libraries: {len(updated_df)} out of {len(df)}")
# Out:
# Library Name                   Current      Latest
# acquit-ignore                  0.2.1        0.2.1
# acquit-require                 0.1.1        0.1.1
# acquit                         1.4.0        1.4.0
# ajv                            8.17.1       8.17.1
# assert-browserify              2.0.0        2.0.0
# broken-link-checker            0.7.8        0.7.8
# bson                           6.10.4       6.10.4
# cheerio                        1.1.2        1.1.2
# crypto-browserify              3.12.1       3.12.1
# dox                            1.0.0        1.0.0
#
# Total up-to-date libraries: 1298 out of 3870

# %% [markdown]
# ## Graph: Risk Assessment by OSS Project

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool, LabelSet
import pandas as pd

# Enable Bokeh in Colab
output_notebook()

# Load version results
version_results = pd.read_csv('npm_version_check_results.csv')
outdated_libraries = set(version_results[version_results['Status'].str.contains('Update available', na=False)]['Library'])

# Define severity weights for risk calculation
severity_weights = {
    'CRITICAL': 20,
    'HIGH': 10,
    'MODERATE': 5,
    'LOW': 2
}

# Calculate risk for each project
project_data = []

for project in libraries_df['Project Name'].unique():
    project_libs = libraries_df[libraries_df['Project Name'] == project]

    # Merge with vulnerabilities
    project_vulns = project_libs.merge(
        vulnerabilities_df,
        left_on=['Library Name', 'Library Version'],
        right_on=['name', 'version'],
        how='inner'
    )

    # Count vulnerabilities by severity
    severity_counts = project_vulns['severity'].value_counts()
    critical_count = severity_counts.get('CRITICAL', 0)
    high_count = severity_counts.get('HIGH', 0)
    moderate_count = severity_counts.get('MODERATE', 0)
    low_count = severity_counts.get('LOW', 0)

    # Calculate weighted vulnerability score
    vuln_score = (critical_count * severity_weights['CRITICAL'] +
                  high_count * severity_weights['HIGH'] +
                  moderate_count * severity_weights['MODERATE'] +
                  low_count * severity_weights['LOW'])

    # Count outdated libraries
    outdated_count = project_libs['Library Name'].isin(outdated_libraries).sum()

    # Count missing authors
    author_missing = project_libs['Library Author'].isna().sum()

    # Calculate total risk score
    risk_score = vuln_score + (outdated_count * 3) + (author_missing * 1)
    library_count = len(project_libs)
    total_vulns = len(project_vulns)

    project_data.append({
        'Project': project,
        'Risk_Score': risk_score,
        'Library_Count': library_count,
        'Total_Vulns': total_vulns,
        'Critical': critical_count,
        'High': high_count,
        'Moderate': moderate_count,
        'Low': low_count,
        'Outdated': outdated_count,
        'No_Author': author_missing,
        'Vuln_Score': vuln_score
    })

# Create DataFrame
df = pd.DataFrame(project_data)

# Calculate medians for quadrants
risk_median = df['Risk_Score'].median()
lib_median = df['Library_Count'].median()

# Assign colors based on quadrants
def get_color(risk, libs):
    if risk <= risk_median and libs <= lib_median:
        return 'green'    # Low risk, few libs
    elif risk <= risk_median and libs > lib_median:
        return 'yellow'   # Low risk, many libs
    elif risk > risk_median and libs <= lib_median:
        return 'orange'   # High risk, few libs
    else:
        return 'red'      # High risk, many libs

df['Color'] = df.apply(lambda row: get_color(row['Risk_Score'], row['Library_Count']), axis=1)

# Create plot
source = ColumnDataSource(df)

p = figure(title="Project Risk Assessment - Enhanced with Severity Weights",
           x_axis_label="Risk Score (Weighted by Severity)",
           y_axis_label="Library Count",
           width=800, height=600)

p.scatter('Risk_Score', 'Library_Count', size=12, alpha=0.7,
          color='Color', source=source)

# Add project names above points
labels = LabelSet(x='Risk_Score', y='Library_Count', text='Project',
                 x_offset=0, y_offset=12, source=source,
                 text_font_size="9pt", text_color="black", text_align="center")
p.add_layout(labels)

# Add quadrant lines
p.line([risk_median, risk_median], [0, df['Library_Count'].max()],
       line_color='gray', line_dash='dashed', alpha=0.5, line_width=2)
p.line([0, df['Risk_Score'].max()], [lib_median, lib_median],
       line_color='gray', line_dash='dashed', alpha=0.5, line_width=2)

# Enhanced hover with severity breakdown
hover = HoverTool(tooltips=[
    ('Project', '@Project'),
    ('Risk Score', '@Risk_Score'),
    ('Libraries', '@Library_Count'),
    ('Total Vulns', '@Total_Vulns'),
    ('Critical', '@Critical'),
    ('High', '@High'),
    ('Moderate', '@Moderate'),
    ('Low', '@Low'),
    ('Outdated', '@Outdated'),
    ('No Author', '@No_Author'),
    ('Vuln Score', '@Vuln_Score')
])
p.add_tools(hover)

show(p)

print(f"\nTop Highest Risk Projects:")
top_risk = df.nlargest(4, 'Risk_Score')[['Project', 'Risk_Score', 'Critical', 'High', 'Outdated']]
print(top_risk.to_string(index=False))
# Out:
#   <div id="e1da74e2-ba65-4076-8e69-bea52a9bd8bc" data-root-id="p1168" style="display: contents;"></div>
# Top Highest Risk Projects:
#   Project  Risk_Score  Critical  High  Outdated
# socket.io        3373         1    16       943
#    lodash        3331        23    84       513
#      jest        2387         0     0       703
#  mongoose        2249         0     2       687

# %% [markdown]
# ## OSS Projects Risk Compositions

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import ColumnDataSource, HoverTool
import pandas as pd

# Enable Bokeh in Colab
output_notebook()

# Load version results
version_results = pd.read_csv('npm_version_check_results.csv')
outdated_libraries = set(version_results[version_results['Status'].str.contains('Update available', na=False)]['Library'])

# Define severity weights
severity_weights = {
    'CRITICAL': 20,
    'HIGH': 10,
    'MODERATE': 5,
    'LOW': 2
}

# Calculate risk for each project
project_data = []

for project in libraries_df['Project Name'].unique():
    project_libs = libraries_df[libraries_df['Project Name'] == project]

    # Merge with vulnerabilities
    project_vulns = project_libs.merge(
        vulnerabilities_df,
        left_on=['Library Name', 'Library Version'],
        right_on=['name', 'version'],
        how='inner'
    )

    # Count vulnerabilities by severity
    severity_counts = project_vulns['severity'].value_counts()
    critical_count = severity_counts.get('CRITICAL', 0)
    high_count = severity_counts.get('HIGH', 0)
    moderate_count = severity_counts.get('MODERATE', 0)
    low_count = severity_counts.get('LOW', 0)

    # Calculate weighted vulnerability score
    vuln_score = (critical_count * severity_weights['CRITICAL'] +
                  high_count * severity_weights['HIGH'] +
                  moderate_count * severity_weights['MODERATE'] +
                  low_count * severity_weights['LOW'])

    # Count outdated libraries and missing authors
    outdated_count = project_libs['Library Name'].isin(outdated_libraries).sum()
    author_missing = project_libs['Library Author'].isna().sum()

    # Calculate scores for each component
    critical_score = critical_count * 20
    high_score = high_count * 10
    moderate_score = moderate_count * 5
    low_score = low_count * 2
    outdated_score = outdated_count * 3
    missing_score = author_missing * 1

    # Calculate total risk score
    total_risk_score = critical_score + high_score + moderate_score + low_score + outdated_score + missing_score

    project_data.append({
        'Project': project,
        'Risk_Score': total_risk_score,
        'Critical': critical_count,
        'High': high_count,
        'Moderate': moderate_count,
        'Low': low_count,
        'Outdated': outdated_count,
        'Missing_Authors': author_missing,
        'Critical_Score': critical_score,
        'High_Score': high_score,
        'Moderate_Score': moderate_score,
        'Low_Score': low_score,
        'Outdated_Score': outdated_score,
        'Missing_Score': missing_score
    })

# Create DataFrame and sort by risk score
df = pd.DataFrame(project_data)
df = df.sort_values('Risk_Score', ascending=False)

# Calculate stacking positions
df['critical_bottom'] = 0
df['critical_top'] = df['Critical_Score']

df['high_bottom'] = df['critical_top']
df['high_top'] = df['high_bottom'] + df['High_Score']

df['moderate_bottom'] = df['high_top']
df['moderate_top'] = df['moderate_bottom'] + df['Moderate_Score']

df['low_bottom'] = df['moderate_top']
df['low_top'] = df['low_bottom'] + df['Low_Score']

df['outdated_bottom'] = df['low_top']
df['outdated_top'] = df['outdated_bottom'] + df['Outdated_Score']

df['missing_bottom'] = df['outdated_top']
df['missing_top'] = df['missing_bottom'] + df['Missing_Score']

# Create the stacked bar chart
source = ColumnDataSource(df)

p = figure(x_range=df['Project'].tolist(),
           title="OSS Projects Risk Composition - Stacked by Risk Components",
           x_axis_label="Projects",
           y_axis_label="Risk Score",
           width=1200, height=600)

# Create stacked bars - only add if value > 0 to avoid empty segments
if df['Critical_Score'].sum() > 0:
    p.vbar(x='Project', bottom='critical_bottom', top='critical_top', width=0.8,
           color='#8B0000', source=source, alpha=0.9, legend_label="Critical CVEs")

if df['High_Score'].sum() > 0:
    p.vbar(x='Project', bottom='high_bottom', top='high_top', width=0.8,
           color='#FF0000', source=source, alpha=0.9, legend_label="High CVEs")

if df['Moderate_Score'].sum() > 0:
    p.vbar(x='Project', bottom='moderate_bottom', top='moderate_top', width=0.8,
           color='#FF8C00', source=source, alpha=0.9, legend_label="Moderate CVEs")

if df['Low_Score'].sum() > 0:
    p.vbar(x='Project', bottom='low_bottom', top='low_top', width=0.8,
           color='#FFD700', source=source, alpha=0.9, legend_label="Low CVEs")

if df['Outdated_Score'].sum() > 0:
    p.vbar(x='Project', bottom='outdated_bottom', top='outdated_top', width=0.8,
           color='#4169E1', source=source, alpha=0.9, legend_label="Outdated Libraries")

if df['Missing_Score'].sum() > 0:
    p.vbar(x='Project', bottom='missing_bottom', top='missing_top', width=0.8,
           color='#808080', source=source, alpha=0.9, legend_label="Missing Authors")

# Configure chart
p.xaxis.major_label_orientation = 45
p.legend.location = "top_right"
p.legend.click_policy = "hide"

# Add hover tooltip
hover = HoverTool(tooltips=[
    ('Project', '@Project'),
    ('Total Risk Score', '@Risk_Score'),
    ('', ''),
    ('Critical CVEs', '@Critical (@Critical_Score pts)'),
    ('High CVEs', '@High (@High_Score pts)'),
    ('Moderate CVEs', '@Moderate (@Moderate_Score pts)'),
    ('Low CVEs', '@Low (@Low_Score pts)'),
    ('Outdated Libraries', '@Outdated (@Outdated_Score pts)'),
    ('Missing Authors', '@Missing_Authors (@Missing_Score pts)')
])
p.add_tools(hover)

show(p)
print("\n")
print(df[['Project', 'Risk_Score', 'Critical', 'High', 'Moderate', 'Low', 'Outdated', 'Missing_Authors']].to_string(index=False))
# Out:
#   <div id="ac4ff07a-4c61-448a-a4b7-3e5ce94b8b5e" data-root-id="p4524" style="display: contents;"></div>
#     Project  Risk_Score  Critical  High  Moderate  Low  Outdated  Missing_Authors
#   socket.io        3373         1    16         4   40       943              264
#      lodash        3331        23    84        56   13       513              186
#        jest        2387         0     0         0    0       703              278
#    mongoose        2249         0     2         2    3       687              152
#      dotenv        2096         0     0         1   41       641               86
#       chalk        1929         1     6        11    3       571               75
#       axios        1803         0     0         0   11       522              215
#      bcrypt         714         0     1         0    5       201               91
# tailwindcss         467         0     0         1    0       117              111
#    passport         214         3     4         3    1        31                4

# %% [markdown]
# ## Export a html file

# %%
from bokeh.plotting import figure, output_file, save
from bokeh.models import ColumnDataSource, HoverTool, LabelSet
from bokeh.layouts import column
from bokeh.models import Div
import pandas as pd

# Set output to HTML file
output_file("index.html")

# Load version results
version_results = pd.read_csv('npm_version_check_results.csv')
outdated_libraries = set(version_results[version_results['Status'].str.contains('Update available', na=False)]['Library'])

# Define severity weights
severity_weights = {
    'CRITICAL': 20,
    'HIGH': 10,
    'MODERATE': 5,
    'LOW': 2
}

# Calculate risk for each project
project_data = []

for project in libraries_df['Project Name'].unique():
    project_libs = libraries_df[libraries_df['Project Name'] == project]

    # Merge with vulnerabilities
    project_vulns = project_libs.merge(
        vulnerabilities_df,
        left_on=['Library Name', 'Library Version'],
        right_on=['name', 'version'],
        how='inner'
    )

    # Count vulnerabilities by severity
    severity_counts = project_vulns['severity'].value_counts()
    critical_count = severity_counts.get('CRITICAL', 0)
    high_count = severity_counts.get('HIGH', 0)
    moderate_count = severity_counts.get('MODERATE', 0)
    low_count = severity_counts.get('LOW', 0)

    # Calculate weighted vulnerability score
    vuln_score = (critical_count * severity_weights['CRITICAL'] +
                  high_count * severity_weights['HIGH'] +
                  moderate_count * severity_weights['MODERATE'] +
                  low_count * severity_weights['LOW'])

    # Count outdated libraries and missing authors
    outdated_count = project_libs['Library Name'].isin(outdated_libraries).sum()
    author_missing = project_libs['Library Author'].isna().sum()

    # Calculate scores for each component
    critical_score = critical_count * 20
    high_score = high_count * 10
    moderate_score = moderate_count * 5
    low_score = low_count * 2
    outdated_score = outdated_count * 3
    missing_score = author_missing * 1

    # Calculate total risk score
    total_risk_score = critical_score + high_score + moderate_score + low_score + outdated_score + missing_score
    library_count = len(project_libs)
    total_vulns = len(project_vulns)

    project_data.append({
        'Project': project,
        'Risk_Score': total_risk_score,
        'Library_Count': library_count,
        'Total_Vulns': total_vulns,
        'Critical': critical_count,
        'High': high_count,
        'Moderate': moderate_count,
        'Low': low_count,
        'Outdated': outdated_count,
        'Missing_Authors': author_missing,
        'Vuln_Score': vuln_score,
        'Critical_Score': critical_score,
        'High_Score': high_score,
        'Moderate_Score': moderate_score,
        'Low_Score': low_score,
        'Outdated_Score': outdated_score,
        'Missing_Score': missing_score
    })

# Create DataFrame
df = pd.DataFrame(project_data)

# GRAPH 1: RISK ASSESSMENT SCATTER PLOT

# Calculate medians for quadrants
risk_median = df['Risk_Score'].median()
lib_median = df['Library_Count'].median()

# Assign colors based on quadrants
def get_color(risk, libs):
    if risk <= risk_median and libs <= lib_median:
        return 'green'    # Low risk, few libs
    elif risk <= risk_median and libs > lib_median:
        return 'yellow'   # Low risk, many libs
    elif risk > risk_median and libs <= lib_median:
        return 'orange'   # High risk, few libs
    else:
        return 'red'      # High risk, many libs

df['Color'] = df.apply(lambda row: get_color(row['Risk_Score'], row['Library_Count']), axis=1)

# Create first plot - scatter plot
source1 = ColumnDataSource(df)

p1 = figure(title="Project Risk Assessment - Enhanced with Severity Weights",
           x_axis_label="Risk Score (Weighted by Severity)",
           y_axis_label="Library Count",
           width=800, height=600)

p1.scatter('Risk_Score', 'Library_Count', size=12, alpha=0.7,
          color='Color', source=source1)

# Add project names above points
labels = LabelSet(x='Risk_Score', y='Library_Count', text='Project',
                 x_offset=0, y_offset=12, source=source1,
                 text_font_size="9pt", text_color="black", text_align="center")
p1.add_layout(labels)

# Add quadrant lines
p1.line([risk_median, risk_median], [0, df['Library_Count'].max()],
       line_color='gray', line_dash='dashed', alpha=0.5, line_width=2)
p1.line([0, df['Risk_Score'].max()], [lib_median, lib_median],
       line_color='gray', line_dash='dashed', alpha=0.5, line_width=2)

# Enhanced hover with severity breakdown
hover1 = HoverTool(tooltips=[
    ('Project', '@Project'),
    ('Risk Score', '@Risk_Score'),
    ('Libraries', '@Library_Count'),
    ('Total Vulns', '@Total_Vulns'),
    ('Critical', '@Critical'),
    ('High', '@High'),
    ('Moderate', '@Moderate'),
    ('Low', '@Low'),
    ('Outdated', '@Outdated'),
    ('Missing Authors', '@Missing_Authors'),
    ('Vuln Score', '@Vuln_Score')
])
p1.add_tools(hover1)

# GRAPH 2: STACKED BAR CHART

# Sort by risk score for bar chart
df_sorted = df.sort_values('Risk_Score', ascending=False)

# Calculate stacking positions
df_sorted['critical_bottom'] = 0
df_sorted['critical_top'] = df_sorted['Critical_Score']

df_sorted['high_bottom'] = df_sorted['critical_top']
df_sorted['high_top'] = df_sorted['high_bottom'] + df_sorted['High_Score']

df_sorted['moderate_bottom'] = df_sorted['high_top']
df_sorted['moderate_top'] = df_sorted['moderate_bottom'] + df_sorted['Moderate_Score']

df_sorted['low_bottom'] = df_sorted['moderate_top']
df_sorted['low_top'] = df_sorted['low_bottom'] + df_sorted['Low_Score']

df_sorted['outdated_bottom'] = df_sorted['low_top']
df_sorted['outdated_top'] = df_sorted['outdated_bottom'] + df_sorted['Outdated_Score']

df_sorted['missing_bottom'] = df_sorted['outdated_top']
df_sorted['missing_top'] = df_sorted['missing_bottom'] + df_sorted['Missing_Score']

# Create second plot - stacked bar chart
source2 = ColumnDataSource(df_sorted)

p2 = figure(x_range=df_sorted['Project'].tolist(),
           title="OSS Projects Risk Composition - Stacked by Risk Components",
           x_axis_label="Projects",
           y_axis_label="Risk Score",
           width=1200, height=600)

# Create stacked bars - only add if value > 0 to avoid empty segments
if df_sorted['Critical_Score'].sum() > 0:
    p2.vbar(x='Project', bottom='critical_bottom', top='critical_top', width=0.8,
           color='#8B0000', source=source2, alpha=0.9, legend_label="Critical CVEs")

if df_sorted['High_Score'].sum() > 0:
    p2.vbar(x='Project', bottom='high_bottom', top='high_top', width=0.8,
           color='#FF0000', source=source2, alpha=0.9, legend_label="High CVEs")

if df_sorted['Moderate_Score'].sum() > 0:
    p2.vbar(x='Project', bottom='moderate_bottom', top='moderate_top', width=0.8,
           color='#FF8C00', source=source2, alpha=0.9, legend_label="Moderate CVEs")

if df_sorted['Low_Score'].sum() > 0:
    p2.vbar(x='Project', bottom='low_bottom', top='low_top', width=0.8,
           color='#FFD700', source=source2, alpha=0.9, legend_label="Low CVEs")

if df_sorted['Outdated_Score'].sum() > 0:
    p2.vbar(x='Project', bottom='outdated_bottom', top='outdated_top', width=0.8,
           color='#4169E1', source=source2, alpha=0.9, legend_label="Outdated Libraries")

if df_sorted['Missing_Score'].sum() > 0:
    p2.vbar(x='Project', bottom='missing_bottom', top='missing_top', width=0.8,
           color='#808080', source=source2, alpha=0.9, legend_label="Missing Authors")

# Configure second chart
p2.xaxis.major_label_orientation = 45
p2.legend.location = "top_right"
p2.legend.click_policy = "hide"

# Add hover tooltip
hover2 = HoverTool(tooltips=[
    ('Project', '@Project'),
    ('Total Risk Score', '@Risk_Score'),
    ('', ''),
    ('Critical CVEs', '@Critical (@Critical_Score pts)'),
    ('High CVEs', '@High (@High_Score pts)'),
    ('Moderate CVEs', '@Moderate (@Moderate_Score pts)'),
    ('Low CVEs', '@Low (@Low_Score pts)'),
    ('Outdated Libraries', '@Outdated (@Outdated_Score pts)'),
    ('Missing Authors', '@Missing_Authors (@Missing_Score pts)')
])
p2.add_tools(hover2)

# CREATE LAYOUT AND SAVE

# Add title and description
title_div = Div(text="""
<h1 style="text-align: center; color: #2F4F4F;">OSS Projects Security Risk Assessment Dashboard</h1>
<p style="text-align: center; font-size: 14px; color: #666;">
Analysis of Open Source Software projects showing risk scores based on CVE severity, outdated libraries, and missing authors.
</p>
<hr>
""", width=1200, height=80)

description1 = Div(text="""
<h2 style="color: #2F4F4F;">Graph 1: Risk vs Library Count Quadrant Analysis</h2>
""", width=800, height=60)

description2 = Div(text="""
<h2 style="color: #2F4F4F; margin-top: 30px; margin-bottom: 10px;">Graph 2: OSS Projects by Risk Composition</h2>
""", width=1000, height=60)

# Add footer
footer_div = Div(text="""
<div style="text-align: center; width: 100%; margin: 50px auto 20px auto;">
<p style="color: #7a7a7a; font-size: 12px;">danbreu.com</p>
</div>
""", width=1200, height=50)

# Combine all elements in a layout with center alignment
layout = column(title_div, description1, p1, description2, p2, footer_div,
                sizing_mode="fixed", margin=(0, 100, 0, 100))  # Center the entire layout

# Save to HTML file
save(layout)

print("Successfully exported both graphs to 'index.html'")
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: Column(id='p4321', ...)
# Successfully exported both graphs to 'index.html'
